# %% [markdown]
# # TensorFlow script mode training and serving
# Script mode is a training script format for TensorFlow that lets you execute any TensorFlow training script in SageMaker with minimal modification. The [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) handles transferring your script to a SageMaker training instance. On the training instance, SageMaker's native TensorFlow support sets up training-related environment variables and executes your training script. In this tutorial, we use the SageMaker Python SDK to launch a training job and deploy the trained model.
#
# Script mode supports training with a Python script, a Python module, or a shell script. In this example, we use a Python script to train a classification model on the [MNIST dataset](http://yann.lecun.com/exdb/mnist/). In this example, we will show how easily you can train a SageMaker using TensorFlow 1.x and TensorFlow 2.0 scripts with SageMaker Python SDK. In addition, this notebook demonstrates how to perform real time inference with the [SageMaker TensorFlow Serving container](https://github.com/aws/sagemaker-tensorflow-serving-container). The TensorFlow Serving container is the default inference method for script mode. For full documentation on the TensorFlow Serving container, please visit [here](https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/deploying_tensorflow_serving.rst).

# %% [markdown]
# # Set up the environment
# Let's start by setting up the environment:

# %%
# cell 01
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %% [markdown]
# # Training Data
# The MNIST dataset has been loaded to the public S3 buckets `sagemaker-sample-data-<REGION>` under the prefix `tensorflow/mnist`. There are four .npy file under this prefix:
#
# - train_data.npy
# - eval_data.npy
# - train_labels.npy
# - eval_labels.npy

# %%
# cell 02
training_data_uri = 's3://sagemaker-sample-data-{}/tensorflow/mnist'.format(region)

# %% [markdown]
# # Construct a script for distributed training
# This tutorial's training script was adapted from TensorFlow's official [CNN MNIST example](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/tutorials/layers/cnn_mnist.py). We have modified it to handle the `model_dir` parameter passed in by SageMaker. This is an S3 path which can be used for data sharing during distributed training and checkpointing and/or model persistence. We have also added an argument-parsing function to handle processing training-related variables.
#
# At the end of the training job we have added a step to export the trained model to the path stored in the environment variable `SM_MODEL_DIR`, which always points to `/opt/ml/model`. This is critical because SageMaker uploads all the model artifacts in this folder to S3 at end of training.
#
# Here is the entire script:

# %%
# cell 03

# !pygmentize 'mnist.py'

# TensorFlow 2.1 script
# !pygmentize 'mnist-2.py'
# Out:
# # Copyright 2018-2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.
# """Convolutional Neural Network Estimator for MNIST, built with tf.layers."""
#
# from __future__ import absolute_import
# from __future__ import division
# from __future__ import print_function
#
# import numpy as np
# import tensorflow as tf
# import os
# import json
# import argparse
# from tensorflow.python.platform import tf_logging
# import logging as _logging
# import sys as _sys
#
#
# def cnn_model_fn(features, labels, mode):
#     """Model function for CNN."""
#     # Input Layer
#     # Reshape X to 4-D tensor: [batch_size, width, height, channels]
#     # MNIST images are 28x28 pixels, and have one color channel
#     input_layer = tf.reshape(features["x"], [-1, 28, 28, 1])
#
#     # Convolutional Layer #1
#     # Computes 32 features using a 5x5 filter with ReLU activation.
#     # Padding is added to preserve width and height.
#     # Input Tensor Shape: [batch_size, 28, 28, 1]
#     # Output Tensor Shape: [batch_size, 28, 28, 32]
#     conv1 = tf.layers.conv2d(
#         inputs=input_layer,
#         filters=32,
#         kernel_size=[5, 5],
#         padding="same",
#         activation=tf.nn.relu)
#
#     # Pooling Layer #1
#     # First max pooling layer with a 2x2 filter and stride of 2
#     # Input Tensor Shape: [batch_size, 28, 28, 32]
#     # Output Tensor Shape: [batch_size, 14, 14, 32]
#     pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
#
#     # Convolutional Layer #2
#     # Computes 64 features using a 5x5 filter.
#     # Padding is added to preserve width and height.
#     # Input Tensor Shape: [batch_size, 14, 14, 32]
#     # Output Tensor Shape: [batch_size, 14, 14, 64]
#     conv2 = tf.layers.conv2d(
#         inputs=pool1,
#         filters=64,
#         kernel_size=[5, 5],
#         padding="same",
#         activation=tf.nn.relu)
#
#     # Pooling Layer #2
#     # Second max pooling layer with a 2x2 filter and stride of 2
#     # Input Tensor Shape: [batch_size, 14, 14, 64]
#     # Output Tensor Shape: [batch_size, 7, 7, 64]
#     pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
#
#     # Flatten tensor into a batch of vectors
#     # Input Tensor Shape: [batch_size, 7, 7, 64]
#     # Output Tensor Shape: [batch_size, 7 * 7 * 64]
#     pool2_flat = tf.reshape(pool2, [-1, 7 * 7 * 64])
#
#     # Dense Layer
#     # Densely connected layer with 1024 neurons
#     # Input Tensor Shape: [batch_size, 7 * 7 * 64]
#     # Output Tensor Shape: [batch_size, 1024]
#     dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
#
#     # Add dropout operation; 0.6 probability that element will be kept
#     dropout = tf.layers.dropout(
#         inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)
#
#     # Logits layer
#     # Input Tensor Shape: [batch_size, 1024]
#     # Output Tensor Shape: [batch_size, 10]
#     logits = tf.layers.dense(inputs=dropout, units=10)
#
#     predictions = {
#         # Generate predictions (for PREDICT and EVAL mode)
#         "classes": tf.argmax(input=logits, axis=1),
#         # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
#         # `logging_hook`.
#         "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
#     }
#     if mode == tf.estimator.ModeKeys.PREDICT:
#       return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
#
#     # Calculate Loss (for both TRAIN and EVAL modes)
#     loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
#
#     # Configure the Training Op (for TRAIN mode)
#     if mode == tf.estimator.ModeKeys.TRAIN:
#       optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
#       train_op = optimizer.minimize(
#           loss=loss,
#           global_step=tf.train.get_global_step())
#       return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
#
#     # Add evaluation metrics (for EVAL mode)
#     eval_metric_ops = {
#         "accuracy": tf.metrics.accuracy(
#             labels=labels, predictions=predictions["classes"])}
#     return tf.estimator.EstimatorSpec(
#         mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)
#
# def _load_training_data(base_dir):
#     x_train = np.load(os.path.join(base_dir, 'train_data.npy'))
#     y_train = np.load(os.path.join(base_dir, 'train_labels.npy'))
#     return x_train, y_train
#
# def _load_testing_data(base_dir):
#     x_test = np.load(os.path.join(base_dir, 'eval_data.npy'))
#     y_test = np.load(os.path.join(base_dir, 'eval_labels.npy'))
#     return x_test, y_test
#
# def _parse_args():
#
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument('--model_dir', type=str)
#     parser.add_argument('--sm-model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
#     parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAINING'))
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ.get('SM_HOSTS')))
#     parser.add_argument('--current-host', type=str, default=os.environ.get('SM_CURRENT_HOST'))
#
#     return parser.parse_known_args()
#
# def serving_input_fn():
#     inputs = {'x': tf.placeholder(tf.float32, [None, 784])}
#     return tf.estimator.export.ServingInputReceiver(inputs, inputs)
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_training_data(args.train)
#     eval_data, eval_labels = _load_testing_data(args.train)
#
#     # Create the Estimator
#     mnist_classifier = tf.estimator.Estimator(
#         model_fn=cnn_model_fn, model_dir=args.model_dir)
#
#     # Set up logging for predictions
#     # Log the values in the "Softmax" tensor with label "probabilities"
#     tensors_to_log = {"probabilities": "softmax_tensor"}
#     logging_hook = tf.train.LoggingTensorHook(
#         tensors=tensors_to_log, every_n_iter=50)
#
#     # Train the model
#     train_input_fn = tf.estimator.inputs.numpy_input_fn(
#         x={"x": train_data},
#         y=train_labels,
#         batch_size=100,
#         num_epochs=None,
#         shuffle=True)
#
#     # Evaluate the model and print results
#     eval_input_fn = tf.estimator.inputs.numpy_input_fn(
#         x={"x": eval_data},
#         y=eval_labels,
#         num_epochs=1,
#         shuffle=False)
#
#     train_spec = tf.estimator.TrainSpec(train_input_fn, max_steps=20000)
#     eval_spec = tf.estimator.EvalSpec(eval_input_fn)
#     tf.estimator.train_and_evaluate(mnist_classifier, train_spec, eval_spec)
#
#     if args.current_host == args.hosts[0]:
#         mnist_classifier.export_savedmodel(args.sm_model_dir, serving_input_fn)
# # Copyright 2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.import tensorflow as tf
#
# import tensorflow as tf
# import argparse
# import os
# import numpy as np
# import json
#
#
# def model(x_train, y_train, x_test, y_test):
#     """Generate a simple model"""
#     model = tf.keras.models.Sequential([
#         tf.keras.layers.Flatten(),
#         tf.keras.layers.Dense(1024, activation=tf.nn.relu),
#         tf.keras.layers.Dropout(0.4),
#         tf.keras.layers.Dense(10, activation=tf.nn.softmax)
#     ])
#
#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#     model.fit(x_train, y_train)
#     model.evaluate(x_test, y_test)
#
#     return model
#
#
# def _load_training_data(base_dir):
#     """Load MNIST training data"""
#     x_train = np.load(os.path.join(base_dir, 'train_data.npy'))
#     y_train = np.load(os.path.join(base_dir, 'train_labels.npy'))
#     return x_train, y_train
#
#
# def _load_testing_data(base_dir):
#     """Load MNIST testing data"""
#     x_test = np.load(os.path.join(base_dir, 'eval_data.npy'))
#     y_test = np.load(os.path.join(base_dir, 'eval_labels.npy'))
#     return x_test, y_test
#
#
# def _parse_args():
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument('--model_dir', type=str)
#     parser.add_argument('--sm-model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
#     parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAINING'))
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ.get('SM_HOSTS')))
#     parser.add_argument('--current-host', type=str, default=os.environ.get('SM_CURRENT_HOST'))
#
#     return parser.parse_known_args()
#
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_training_data(args.train)
#     eval_data, eval_labels = _load_testing_data(args.train)
#
#     mnist_classifier = model(train_data, train_labels, eval_data, eval_labels)
#
#     if args.current_host == args.hosts[0]:
#         # save model to an S3 directory with version number '00000001' in Tensorflow SavedModel Format
#         # To export the model as h5 format use model.save('my_model.h5')
#         mnist_classifier.save(os.path.join(args.sm_model_dir, '000000001'))

# %% [markdown]
# # Create a training job using the TensorFlow estimator
# The `sagemaker.tensorflow.TensorFlow` estimator handles locating the script mode container, uploading your script to a S3 location and creating a SageMaker training job. Let's call out a couple important parameters here:
#
# `py_version` is set to `'py3'` to indicate that we are using script mode since legacy mode supports only Python 2. Though Python 2 will be deprecated soon, you can use script mode with Python 2 by setting py_version to `py2` and `script_mode` to True.
#
# `distribution` is used to configure the distributed training setup. It's required only if you are doing distributed training either across a cluster of instances or across multiple GPUs. Here we are using parameter servers as the distributed training schema. SageMaker training jobs run on homogeneous clusters. To make parameter server more performant in the SageMaker setup, we run a parameter server on every instance in the cluster, so there is no need to specify the number of parameter servers to launch. Script mode also supports distributed training with [Horovod](https://github.com/horovod/horovod). You can find the full documentation on how to configure distributions [here](https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#distributed-training).

# %%
# cell 04
from sagemaker.tensorflow import TensorFlow


mnist_estimator = TensorFlow(entry_point='mnist.py',
                             role=role,
                             instance_count=2,
                             instance_type='ml.p3.2xlarge',
                             framework_version='1.15.2',
                             py_version='py3',
                             distribution={'parameter_server': {'enabled': True}})

# %% [markdown]
# You can also initiate an estimator to train with TensorFlow 2.1 script. The only things that you will need to change are the script name and `framework_version`

# %%
# cell 05
mnist_estimator2 = TensorFlow(entry_point='mnist-2.py',
                             role=role,
                             instance_count=2,
                             instance_type='ml.p3.2xlarge',
                             framework_version='2.1.0',
                             py_version='py3',
                             distribution={'parameter_server': {'enabled': True}})

# %% [markdown]
# # Calling `fit`
# To start a training job, we call `estimator.fit(training_data_uri)`.
#
# An S3 location is used here as the input. fit creates a default channel named 'training', which points to this S3 location. In the training script we can then access the training data from the location stored in SM_CHANNEL_TRAINING. fit accepts a couple other types of input as well. See the API doc [here](https://sagemaker.readthedocs.io/en/stable/estimators.html#sagemaker.estimator.EstimatorBase.fit) for details.
#
# When training starts, the TensorFlow container executes mnist.py, passing hyperparameters and model_dir from the estimator as script arguments. Because we didn't define either in this example, no hyperparameters are passed, and model_dir defaults to `s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>`, so the script execution is as follows:
#
# `python mnist.py --model_dir s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>`
#
# When training is complete, the training job will upload the saved model for TensorFlow serving.

# %%
# cell 06
mnist_estimator.fit(training_data_uri)
# Out:
# 2021-04-22 20:29:40 Starting - Starting the training job...
# 2021-04-22 20:30:03 Starting - Launching requested ML instancesProfilerReport-1619123380: InProgress
# ......
# 2021-04-22 20:31:04 Starting - Preparing the instances for training............
# 2021-04-22 20:33:04 Downloading - Downloading input data
# 2021-04-22 20:33:04 Training - Downloading the training image.....WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2021-04-22 20:33:46,155 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-04-22 20:33:46,404 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:33:46,404 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-04-22 20:33:46,404 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-04-22 20:33:46,405 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-04-22 20:33:46,405 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-04-22 20:33:47,202 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-04-22 20:33:47,428 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-04-22-20-29-39-757",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-04-22-20-29-39-757","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist.py --model_dir s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From mnist.py:161: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From mnist.py:165: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:46: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From mnist.py:46: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From mnist.py:52: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:52: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2021-04-22 20:33:49,892 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-04-22 20:33:50,257 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:33:50,257 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-04-22 20:33:50,257 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-04-22 20:33:50,258 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-04-22 20:33:50,258 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# WARNING:tensorflow:From mnist.py:81: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:81: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:103: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From mnist.py:103: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From mnist.py:107: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:107: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:110: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# WARNING:tensorflow:From mnist.py:110: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# 2021-04-22 20:33:51,099 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-04-22 20:33:51,337 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tensorflow-training-2021-04-22-20-29-39-757",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2021-04-22-20-29-39-757","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist.py --model_dir s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model
#
#
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 0 into s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From mnist.py:161: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From mnist.py:165: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
#
# 2021-04-22 20:34:04 Training - Training image download completed. Training in progress.INFO:tensorflow:loss = 2.316748, step = 0
# INFO:tensorflow:loss = 2.316748, step = 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:46: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From mnist.py:46: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From mnist.py:52: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:52: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:81: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:81: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:103: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From mnist.py:103: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From mnist.py:107: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:107: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:110: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# WARNING:tensorflow:From mnist.py:110: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:loss = 2.2882895, step = 100 (5.973 sec)
# INFO:tensorflow:loss = 2.2882895, step = 100 (5.973 sec)
# INFO:tensorflow:loss = 2.2761233, step = 201 (5.866 sec)
# INFO:tensorflow:loss = 2.2761233, step = 201 (5.866 sec)
# INFO:tensorflow:loss = 2.306124, step = 94
# INFO:tensorflow:loss = 2.306124, step = 94
# INFO:tensorflow:global_step/sec: 50.1101
# INFO:tensorflow:global_step/sec: 50.1101
# INFO:tensorflow:loss = 2.249827, step = 347 (2.959 sec)
# INFO:tensorflow:loss = 2.249827, step = 347 (2.959 sec)
# INFO:tensorflow:global_step/sec: 54.0481
# INFO:tensorflow:global_step/sec: 54.0481
# INFO:tensorflow:loss = 2.2569647, step = 490 (2.553 sec)
# INFO:tensorflow:loss = 2.2569647, step = 490 (2.553 sec)
# INFO:tensorflow:global_step/sec: 56.2015
# INFO:tensorflow:global_step/sec: 56.2015
# INFO:tensorflow:loss = 2.2393432, step = 521 (5.966 sec)
# INFO:tensorflow:loss = 2.2393432, step = 521 (5.966 sec)
# INFO:tensorflow:global_step/sec: 55.766
# INFO:tensorflow:global_step/sec: 55.766
# INFO:tensorflow:loss = 2.1789083, step = 633 (2.571 sec)
# INFO:tensorflow:loss = 2.1789083, step = 633 (2.571 sec)
# INFO:tensorflow:global_step/sec: 56.5029
# INFO:tensorflow:global_step/sec: 56.5029
# INFO:tensorflow:loss = 2.1481051, step = 776 (2.537 sec)
# INFO:tensorflow:loss = 2.1481051, step = 776 (2.537 sec)
# INFO:tensorflow:global_step/sec: 55.8121
# INFO:tensorflow:global_step/sec: 55.8121
# INFO:tensorflow:loss = 2.1219375, step = 854 (5.936 sec)
# INFO:tensorflow:loss = 2.1219375, step = 854 (5.936 sec)
# INFO:tensorflow:global_step/sec: 55.2443
# INFO:tensorflow:global_step/sec: 55.2443
# INFO:tensorflow:loss = 2.0665543, step = 920 (2.600 sec)
# INFO:tensorflow:loss = 2.0665543, step = 920 (2.600 sec)
# INFO:tensorflow:global_step/sec: 55.9479
# INFO:tensorflow:global_step/sec: 55.9479
# INFO:tensorflow:loss = 1.9721454, step = 1063 (2.570 sec)
# INFO:tensorflow:loss = 1.9721454, step = 1063 (2.570 sec)
# INFO:tensorflow:global_step/sec: 55.9059
# INFO:tensorflow:global_step/sec: 55.9059
# INFO:tensorflow:global_step/sec: 54.9581
# INFO:tensorflow:global_step/sec: 54.9581
# INFO:tensorflow:loss = 1.8285854, step = 1207 (2.581 sec)
# INFO:tensorflow:loss = 1.8285854, step = 1207 (2.581 sec)
# INFO:tensorflow:loss = 1.7844199, step = 1183 (5.920 sec)
# INFO:tensorflow:loss = 1.7844199, step = 1183 (5.920 sec)
# INFO:tensorflow:global_step/sec: 56.5997
# INFO:tensorflow:global_step/sec: 56.5997
# INFO:tensorflow:loss = 1.6177318, step = 1350 (2.528 sec)
# INFO:tensorflow:loss = 1.6177318, step = 1350 (2.528 sec)
# INFO:tensorflow:global_step/sec: 56.2601
# INFO:tensorflow:global_step/sec: 56.2601
# INFO:tensorflow:loss = 1.4192255, step = 1493 (2.563 sec)
# INFO:tensorflow:loss = 1.4192255, step = 1493 (2.563 sec)
# INFO:tensorflow:global_step/sec: 56.0191
# INFO:tensorflow:global_step/sec: 56.0191
# INFO:tensorflow:loss = 1.2392576, step = 1515 (5.923 sec)
# INFO:tensorflow:loss = 1.2392576, step = 1515 (5.923 sec)
# INFO:tensorflow:global_step/sec: 56.1953
# INFO:tensorflow:global_step/sec: 56.1953
# INFO:tensorflow:loss = 1.1584074, step = 1636 (2.532 sec)
# INFO:tensorflow:loss = 1.1584074, step = 1636 (2.532 sec)
# INFO:tensorflow:global_step/sec: 56.0335
# INFO:tensorflow:global_step/sec: 56.0335
# INFO:tensorflow:loss = 0.9907312, step = 1779 (2.584 sec)
# INFO:tensorflow:loss = 0.9907312, step = 1779 (2.584 sec)
# INFO:tensorflow:global_step/sec: 54.1333
# INFO:tensorflow:global_step/sec: 54.1333
# INFO:tensorflow:loss = 0.9474076, step = 1847 (6.011 sec)
# INFO:tensorflow:loss = 0.9474076, step = 1847 (6.011 sec)
# INFO:tensorflow:global_step/sec: 52.9779
# INFO:tensorflow:global_step/sec: 52.9779
# INFO:tensorflow:loss = 0.82630897, step = 1923 (2.743 sec)
# INFO:tensorflow:loss = 0.82630897, step = 1923 (2.743 sec)
# INFO:tensorflow:global_step/sec: 54.0382
# INFO:tensorflow:global_step/sec: 54.0382
# INFO:tensorflow:loss = 0.9587427, step = 2067 (2.641 sec)
# INFO:tensorflow:loss = 0.9587427, step = 2067 (2.641 sec)
# INFO:tensorflow:global_step/sec: 54.3319
# INFO:tensorflow:global_step/sec: 54.3319
# INFO:tensorflow:loss = 0.65835273, step = 2175 (6.041 sec)
# INFO:tensorflow:loss = 0.65835273, step = 2175 (6.041 sec)
# INFO:tensorflow:global_step/sec: 56.4557
# INFO:tensorflow:global_step/sec: 56.4557
# INFO:tensorflow:loss = 0.5714402, step = 2210 (2.568 sec)
# INFO:tensorflow:loss = 0.5714402, step = 2210 (2.568 sec)
# INFO:tensorflow:global_step/sec: 54.426
# INFO:tensorflow:global_step/sec: 54.426
# INFO:tensorflow:loss = 0.6383529, step = 2357 (3.238 sec)
# INFO:tensorflow:loss = 0.6383529, step = 2357 (3.238 sec)
# INFO:tensorflow:global_step/sec: 34.9375
# INFO:tensorflow:global_step/sec: 34.9375
# INFO:tensorflow:loss = 0.67430985, step = 2489 (6.749 sec)
# INFO:tensorflow:loss = 0.67430985, step = 2489 (6.749 sec)
# INFO:tensorflow:loss = 0.69854563, step = 2504 (3.158 sec)
# INFO:tensorflow:loss = 0.69854563, step = 2504 (3.158 sec)
# INFO:tensorflow:global_step/sec: 55.4967
# INFO:tensorflow:global_step/sec: 55.4967
# INFO:tensorflow:global_step/sec: 56.1254
# INFO:tensorflow:global_step/sec: 56.1254
# INFO:tensorflow:loss = 0.7065825, step = 2647 (2.558 sec)
# INFO:tensorflow:loss = 0.7065825, step = 2647 (2.558 sec)
# INFO:tensorflow:global_step/sec: 54.9826
# INFO:tensorflow:global_step/sec: 54.9826
# INFO:tensorflow:loss = 0.6119769, step = 2791 (2.593 sec)
# INFO:tensorflow:loss = 0.6119769, step = 2791 (2.593 sec)
# INFO:tensorflow:global_step/sec: 56.2055
# INFO:tensorflow:global_step/sec: 56.2055
# INFO:tensorflow:global_step/sec: 55.9047
# INFO:tensorflow:global_step/sec: 55.9047
# INFO:tensorflow:loss = 0.4155927, step = 2934 (2.552 sec)
# INFO:tensorflow:loss = 0.4155927, step = 2934 (2.552 sec)
# INFO:tensorflow:loss = 0.48654062, step = 2820 (5.930 sec)
# INFO:tensorflow:loss = 0.48654062, step = 2820 (5.930 sec)
# INFO:tensorflow:global_step/sec: 55.0435
# INFO:tensorflow:global_step/sec: 55.0435
# INFO:tensorflow:loss = 0.42060256, step = 3078 (2.639 sec)
# INFO:tensorflow:loss = 0.42060256, step = 3078 (2.639 sec)
# INFO:tensorflow:loss = 0.3072973, step = 3148 (5.991 sec)
# INFO:tensorflow:loss = 0.3072973, step = 3148 (5.991 sec)
# INFO:tensorflow:global_step/sec: 54.1661
# INFO:tensorflow:global_step/sec: 54.1661
# INFO:tensorflow:global_step/sec: 54.261
# INFO:tensorflow:global_step/sec: 54.261
# INFO:tensorflow:loss = 0.3272752, step = 3222 (2.679 sec)
# INFO:tensorflow:loss = 0.3272752, step = 3222 (2.679 sec)
# INFO:tensorflow:global_step/sec: 49.1978
# INFO:tensorflow:global_step/sec: 49.1978
# INFO:tensorflow:loss = 0.3297776, step = 3370 (2.955 sec)
# INFO:tensorflow:loss = 0.3297776, step = 3370 (2.955 sec)
# INFO:tensorflow:global_step/sec: 51.5697
# INFO:tensorflow:global_step/sec: 51.5697
# INFO:tensorflow:loss = 0.337512, step = 3515 (2.700 sec)
# INFO:tensorflow:loss = 0.337512, step = 3515 (2.700 sec)
# INFO:tensorflow:global_step/sec: 54.3838
# INFO:tensorflow:global_step/sec: 54.3838
# INFO:tensorflow:loss = 0.4006007, step = 3464 (6.118 sec)
# INFO:tensorflow:loss = 0.4006007, step = 3464 (6.118 sec)
# INFO:tensorflow:global_step/sec: 55.4811
# INFO:tensorflow:global_step/sec: 55.4811
# INFO:tensorflow:loss = 0.4564135, step = 3659 (2.607 sec)
# INFO:tensorflow:loss = 0.4564135, step = 3659 (2.607 sec)
# INFO:tensorflow:global_step/sec: 55.614
# INFO:tensorflow:global_step/sec: 55.614
# INFO:tensorflow:loss = 0.5016788, step = 3795 (5.939 sec)
# INFO:tensorflow:loss = 0.5016788, step = 3795 (5.939 sec)
# INFO:tensorflow:loss = 0.36014378, step = 3802 (2.553 sec)
# INFO:tensorflow:loss = 0.36014378, step = 3802 (2.553 sec)
# INFO:tensorflow:global_step/sec: 55.9603
# INFO:tensorflow:global_step/sec: 55.9603
# INFO:tensorflow:global_step/sec: 56.7497
# INFO:tensorflow:global_step/sec: 56.7497
# INFO:tensorflow:loss = 0.29691526, step = 3945 (2.547 sec)
# INFO:tensorflow:loss = 0.29691526, step = 3945 (2.547 sec)
# INFO:tensorflow:global_step/sec: 55.476
# INFO:tensorflow:global_step/sec: 55.476
# INFO:tensorflow:loss = 0.28022406, step = 4126 (5.930 sec)
# INFO:tensorflow:loss = 0.28022406, step = 4126 (5.930 sec)
# INFO:tensorflow:loss = 0.34428823, step = 4088 (2.558 sec)
# INFO:tensorflow:loss = 0.34428823, step = 4088 (2.558 sec)
# INFO:tensorflow:global_step/sec: 55.5736
# INFO:tensorflow:global_step/sec: 55.5736
# INFO:tensorflow:global_step/sec: 56.0294
# INFO:tensorflow:global_step/sec: 56.0294
# INFO:tensorflow:loss = 0.45427087, step = 4231 (2.571 sec)
# INFO:tensorflow:loss = 0.45427087, step = 4231 (2.571 sec)
# INFO:tensorflow:global_step/sec: 55.5036
# INFO:tensorflow:global_step/sec: 55.5036
# INFO:tensorflow:loss = 0.4992854, step = 4374 (2.562 sec)
# INFO:tensorflow:loss = 0.4992854, step = 4374 (2.562 sec)
# INFO:tensorflow:global_step/sec: 55.8905
# INFO:tensorflow:global_step/sec: 55.8905
# INFO:tensorflow:loss = 0.44849098, step = 4459 (5.952 sec)
# INFO:tensorflow:loss = 0.44849098, step = 4459 (5.952 sec)
# INFO:tensorflow:loss = 0.2721693, step = 4517 (2.539 sec)
# INFO:tensorflow:loss = 0.2721693, step = 4517 (2.539 sec)
# INFO:tensorflow:global_step/sec: 56.3894
# INFO:tensorflow:global_step/sec: 56.3894
# INFO:tensorflow:global_step/sec: 55.3613
# INFO:tensorflow:global_step/sec: 55.3613
# INFO:tensorflow:loss = 0.2052961, step = 4660 (2.588 sec)
# INFO:tensorflow:loss = 0.2052961, step = 4660 (2.588 sec)
# INFO:tensorflow:global_step/sec: 56.0488
# INFO:tensorflow:global_step/sec: 56.0488
# INFO:tensorflow:loss = 0.3015624, step = 4792 (5.956 sec)
# INFO:tensorflow:loss = 0.3015624, step = 4792 (5.956 sec)
# INFO:tensorflow:loss = 0.38691273, step = 4803 (2.549 sec)
# INFO:tensorflow:loss = 0.38691273, step = 4803 (2.549 sec)
# INFO:tensorflow:global_step/sec: 54.992
# INFO:tensorflow:global_step/sec: 54.992
# INFO:tensorflow:global_step/sec: 55.9449
# INFO:tensorflow:global_step/sec: 55.9449
# INFO:tensorflow:loss = 0.26416934, step = 4946 (2.593 sec)
# INFO:tensorflow:loss = 0.26416934, step = 4946 (2.593 sec)
# INFO:tensorflow:global_step/sec: 55.3384
# INFO:tensorflow:global_step/sec: 55.3384
# INFO:tensorflow:loss = 0.25066927, step = 5089 (2.570 sec)
# INFO:tensorflow:loss = 0.25066927, step = 5089 (2.570 sec)
# INFO:tensorflow:loss = 0.21425013, step = 5121 (5.955 sec)
# INFO:tensorflow:loss = 0.21425013, step = 5121 (5.955 sec)
# INFO:tensorflow:global_step/sec: 55.5854
# INFO:tensorflow:global_step/sec: 55.5854
# INFO:tensorflow:global_step/sec: 55.6466
# INFO:tensorflow:global_step/sec: 55.6466
# INFO:tensorflow:loss = 0.48837432, step = 5232 (2.579 sec)
# INFO:tensorflow:loss = 0.48837432, step = 5232 (2.579 sec)
# INFO:tensorflow:global_step/sec: 56.2354
# INFO:tensorflow:global_step/sec: 56.2354
# INFO:tensorflow:loss = 0.35915077, step = 5375 (2.538 sec)
# INFO:tensorflow:loss = 0.35915077, step = 5375 (2.538 sec)
# INFO:tensorflow:global_step/sec: 55.629
# INFO:tensorflow:global_step/sec: 55.629
# INFO:tensorflow:loss = 0.5199221, step = 5453 (5.947 sec)
# INFO:tensorflow:loss = 0.5199221, step = 5453 (5.947 sec)
# INFO:tensorflow:loss = 0.25177184, step = 5518 (2.567 sec)
# INFO:tensorflow:loss = 0.25177184, step = 5518 (2.567 sec)
# INFO:tensorflow:global_step/sec: 55.9882
# INFO:tensorflow:global_step/sec: 55.9882
# INFO:tensorflow:global_step/sec: 56.4358
# INFO:tensorflow:global_step/sec: 56.4358
# INFO:tensorflow:loss = 0.29175472, step = 5661 (2.530 sec)
# INFO:tensorflow:loss = 0.29175472, step = 5661 (2.530 sec)
# INFO:tensorflow:global_step/sec: 55.8958
# INFO:tensorflow:global_step/sec: 55.8958
# INFO:tensorflow:loss = 0.36187518, step = 5787 (5.946 sec)
# INFO:tensorflow:loss = 0.36187518, step = 5787 (5.946 sec)
# INFO:tensorflow:loss = 0.30132452, step = 5804 (2.557 sec)
# INFO:tensorflow:loss = 0.30132452, step = 5804 (2.557 sec)
# INFO:tensorflow:global_step/sec: 56.5027
# INFO:tensorflow:global_step/sec: 56.5027
# INFO:tensorflow:global_step/sec: 55.527
# INFO:tensorflow:global_step/sec: 55.527
# INFO:tensorflow:loss = 0.3095611, step = 5946 (2.553 sec)
# INFO:tensorflow:loss = 0.3095611, step = 5946 (2.553 sec)
# INFO:tensorflow:global_step/sec: 55.3206
# INFO:tensorflow:global_step/sec: 55.3206
# INFO:tensorflow:loss = 0.2850963, step = 6089 (2.581 sec)
# INFO:tensorflow:loss = 0.2850963, step = 6089 (2.581 sec)
# INFO:tensorflow:loss = 0.24382171, step = 6119 (5.981 sec)
# INFO:tensorflow:loss = 0.24382171, step = 6119 (5.981 sec)
# INFO:tensorflow:global_step/sec: 55.3845
# INFO:tensorflow:global_step/sec: 55.3845
# INFO:tensorflow:global_step/sec: 55.1934
# INFO:tensorflow:global_step/sec: 55.1934
# INFO:tensorflow:loss = 0.23086731, step = 6233 (2.607 sec)
# INFO:tensorflow:loss = 0.23086731, step = 6233 (2.607 sec)
# INFO:tensorflow:global_step/sec: 49.5947
# INFO:tensorflow:global_step/sec: 49.5947
# INFO:tensorflow:loss = 0.1744822, step = 6382 (2.951 sec)
# INFO:tensorflow:loss = 0.1744822, step = 6382 (2.951 sec)
# INFO:tensorflow:loss = 0.33648074, step = 6437 (5.996 sec)
# INFO:tensorflow:loss = 0.33648074, step = 6437 (5.996 sec)
# INFO:tensorflow:global_step/sec: 54.6363
# INFO:tensorflow:global_step/sec: 54.6363
# INFO:tensorflow:global_step/sec: 54.1492
# INFO:tensorflow:global_step/sec: 54.1492
# INFO:tensorflow:loss = 0.25649396, step = 6526 (2.626 sec)
# INFO:tensorflow:loss = 0.25649396, step = 6526 (2.626 sec)
# INFO:tensorflow:global_step/sec: 52.3938
# INFO:tensorflow:global_step/sec: 52.3938
# INFO:tensorflow:loss = 0.22924206, step = 6670 (2.701 sec)
# INFO:tensorflow:loss = 0.22924206, step = 6670 (2.701 sec)
# INFO:tensorflow:global_step/sec: 55.1061
# INFO:tensorflow:global_step/sec: 55.1061
# INFO:tensorflow:loss = 0.22718, step = 6765 (6.044 sec)
# INFO:tensorflow:loss = 0.22718, step = 6765 (6.044 sec)
# INFO:tensorflow:loss = 0.4262596, step = 6813 (2.562 sec)
# INFO:tensorflow:loss = 0.4262596, step = 6813 (2.562 sec)
# INFO:tensorflow:global_step/sec: 55.6144
# INFO:tensorflow:global_step/sec: 55.6144
# INFO:tensorflow:global_step/sec: 55.8349
# INFO:tensorflow:global_step/sec: 55.8349
# INFO:tensorflow:loss = 0.25484592, step = 6956 (2.566 sec)
# INFO:tensorflow:loss = 0.25484592, step = 6956 (2.566 sec)
# INFO:tensorflow:global_step/sec: 56.9091
# INFO:tensorflow:global_step/sec: 56.9091
# INFO:tensorflow:loss = 0.20599003, step = 7100 (5.983 sec)
# INFO:tensorflow:loss = 0.20599003, step = 7100 (5.983 sec)
# INFO:tensorflow:loss = 0.2380538, step = 7098 (2.515 sec)
# INFO:tensorflow:loss = 0.2380538, step = 7098 (2.515 sec)
# INFO:tensorflow:global_step/sec: 55.5842
# INFO:tensorflow:global_step/sec: 55.5842
# INFO:tensorflow:global_step/sec: 55.7895
# INFO:tensorflow:global_step/sec: 55.7895
# INFO:tensorflow:loss = 0.27241862, step = 7241 (2.582 sec)
# INFO:tensorflow:loss = 0.27241862, step = 7241 (2.582 sec)
# INFO:tensorflow:global_step/sec: 54.8305
# INFO:tensorflow:global_step/sec: 54.8305
# INFO:tensorflow:loss = 0.2127061, step = 7385 (2.642 sec)
# INFO:tensorflow:loss = 0.2127061, step = 7385 (2.642 sec)
# INFO:tensorflow:loss = 0.19917645, step = 7428 (5.988 sec)
# INFO:tensorflow:loss = 0.19917645, step = 7428 (5.988 sec)
# INFO:tensorflow:global_step/sec: 53.4207
# INFO:tensorflow:global_step/sec: 53.4207
# INFO:tensorflow:global_step/sec: 55.2109
# INFO:tensorflow:global_step/sec: 55.2109
# INFO:tensorflow:loss = 0.23921266, step = 7530 (2.656 sec)
# INFO:tensorflow:loss = 0.23921266, step = 7530 (2.656 sec)
# INFO:tensorflow:global_step/sec: 56.1794
# INFO:tensorflow:global_step/sec: 56.1794
# INFO:tensorflow:loss = 0.20364937, step = 7673 (2.558 sec)
# INFO:tensorflow:loss = 0.20364937, step = 7673 (2.558 sec)
# INFO:tensorflow:global_step/sec: 55.5791
# INFO:tensorflow:global_step/sec: 55.5791
# INFO:tensorflow:loss = 0.12368024, step = 7759 (5.942 sec)
# INFO:tensorflow:loss = 0.12368024, step = 7759 (5.942 sec)
# INFO:tensorflow:loss = 0.10474359, step = 7816 (2.575 sec)
# INFO:tensorflow:loss = 0.10474359, step = 7816 (2.575 sec)
# INFO:tensorflow:global_step/sec: 55.8602
# INFO:tensorflow:global_step/sec: 55.8602
# INFO:tensorflow:global_step/sec: 56.1911
# INFO:tensorflow:global_step/sec: 56.1911
# INFO:tensorflow:loss = 0.21569803, step = 7959 (2.545 sec)
# INFO:tensorflow:loss = 0.21569803, step = 7959 (2.545 sec)
# INFO:tensorflow:global_step/sec: 54.8438
# INFO:tensorflow:global_step/sec: 54.8438
# INFO:tensorflow:loss = 0.39295438, step = 8090 (5.950 sec)
# INFO:tensorflow:loss = 0.39295438, step = 8090 (5.950 sec)
# INFO:tensorflow:loss = 0.30857915, step = 8102 (2.605 sec)
# INFO:tensorflow:loss = 0.30857915, step = 8102 (2.605 sec)
# INFO:tensorflow:global_step/sec: 56.4026
# INFO:tensorflow:global_step/sec: 56.4026
# INFO:tensorflow:global_step/sec: 55.3327
# INFO:tensorflow:global_step/sec: 55.3327
# INFO:tensorflow:loss = 0.21670698, step = 8246 (2.556 sec)
# INFO:tensorflow:loss = 0.21670698, step = 8246 (2.556 sec)
# INFO:tensorflow:global_step/sec: 55.6455
# INFO:tensorflow:global_step/sec: 55.6455
# INFO:tensorflow:loss = 0.18521477, step = 8389 (2.566 sec)
# INFO:tensorflow:loss = 0.18521477, step = 8389 (2.566 sec)
# INFO:tensorflow:global_step/sec: 56.467
# INFO:tensorflow:global_step/sec: 56.467
# INFO:tensorflow:loss = 0.23609528, step = 8422 (5.950 sec)
# INFO:tensorflow:loss = 0.23609528, step = 8422 (5.950 sec)
# INFO:tensorflow:loss = 0.316471, step = 8531 (2.553 sec)
# INFO:tensorflow:loss = 0.316471, step = 8531 (2.553 sec)
# INFO:tensorflow:global_step/sec: 55.3531
# INFO:tensorflow:global_step/sec: 55.3531
# INFO:tensorflow:global_step/sec: 55.5116
# INFO:tensorflow:global_step/sec: 55.5116
# INFO:tensorflow:loss = 0.17294043, step = 8674 (2.556 sec)
# INFO:tensorflow:loss = 0.17294043, step = 8674 (2.556 sec)
# INFO:tensorflow:global_step/sec: 56.1033
# INFO:tensorflow:global_step/sec: 56.1033
# INFO:tensorflow:loss = 0.1703742, step = 8757 (6.011 sec)
# INFO:tensorflow:loss = 0.1703742, step = 8757 (6.011 sec)
# INFO:tensorflow:loss = 0.17845537, step = 8816 (2.565 sec)
# INFO:tensorflow:loss = 0.17845537, step = 8816 (2.565 sec)
# INFO:tensorflow:global_step/sec: 55.5496
# INFO:tensorflow:global_step/sec: 55.5496
# INFO:tensorflow:global_step/sec: 55.552
# INFO:tensorflow:global_step/sec: 55.552
# INFO:tensorflow:loss = 0.28384736, step = 8959 (2.551 sec)
# INFO:tensorflow:loss = 0.28384736, step = 8959 (2.551 sec)
# INFO:tensorflow:global_step/sec: 56.4192
# INFO:tensorflow:global_step/sec: 56.4192
# INFO:tensorflow:loss = 0.18565626, step = 9092 (6.007 sec)
# INFO:tensorflow:loss = 0.18565626, step = 9092 (6.007 sec)
# INFO:tensorflow:loss = 0.24379271, step = 9101 (2.555 sec)
# INFO:tensorflow:loss = 0.24379271, step = 9101 (2.555 sec)
# INFO:tensorflow:global_step/sec: 54.9472
# INFO:tensorflow:global_step/sec: 54.9472
# INFO:tensorflow:global_step/sec: 55.9327
# INFO:tensorflow:global_step/sec: 55.9327
# INFO:tensorflow:loss = 0.29941732, step = 9244 (2.572 sec)
# INFO:tensorflow:loss = 0.29941732, step = 9244 (2.572 sec)
# INFO:tensorflow:global_step/sec: 55.9429
# INFO:tensorflow:global_step/sec: 55.9429
# INFO:tensorflow:loss = 0.24242464, step = 9387 (2.560 sec)
# INFO:tensorflow:loss = 0.24242464, step = 9387 (2.560 sec)
# INFO:tensorflow:loss = 0.26893586, step = 9425 (5.982 sec)
# INFO:tensorflow:loss = 0.26893586, step = 9425 (5.982 sec)
# INFO:tensorflow:global_step/sec: 55.3738
# INFO:tensorflow:global_step/sec: 55.3738
# INFO:tensorflow:loss = 0.25554237, step = 9531 (2.615 sec)
# INFO:tensorflow:loss = 0.25554237, step = 9531 (2.615 sec)
# INFO:tensorflow:global_step/sec: 54.3496
# INFO:tensorflow:global_step/sec: 54.3496
# INFO:tensorflow:global_step/sec: 55.4001
# INFO:tensorflow:global_step/sec: 55.4001
# INFO:tensorflow:loss = 0.2789783, step = 9674 (2.634 sec)
# INFO:tensorflow:loss = 0.2789783, step = 9674 (2.634 sec)
# INFO:tensorflow:loss = 0.2973091, step = 9756 (6.036 sec)
# INFO:tensorflow:loss = 0.2973091, step = 9756 (6.036 sec)
# INFO:tensorflow:global_step/sec: 54.9031
# INFO:tensorflow:global_step/sec: 54.9031
# INFO:tensorflow:loss = 0.14624125, step = 9817 (2.580 sec)
# INFO:tensorflow:loss = 0.14624125, step = 9817 (2.580 sec)
# INFO:tensorflow:global_step/sec: 55.1622
# ...
# INFO:tensorflow:loss = 0.18917856, step = 15405 (2.576 sec)
# INFO:tensorflow:global_step/sec: 55.6534
# INFO:tensorflow:global_step/sec: 55.6534
# INFO:tensorflow:loss = 0.21480297, step = 15547 (2.563 sec)
# INFO:tensorflow:loss = 0.21480297, step = 15547 (2.563 sec)
# INFO:tensorflow:global_step/sec: 54.954
# INFO:tensorflow:global_step/sec: 54.954
# INFO:tensorflow:global_step/sec: 55.7939
# INFO:tensorflow:global_step/sec: 55.7939
# INFO:tensorflow:loss = 0.099457055, step = 15691 (2.602 sec)
# INFO:tensorflow:loss = 0.099457055, step = 15691 (2.602 sec)
# INFO:tensorflow:loss = 0.14195862, step = 15717 (5.999 sec)
# INFO:tensorflow:loss = 0.14195862, step = 15717 (5.999 sec)
# INFO:tensorflow:global_step/sec: 55.5277
# INFO:tensorflow:global_step/sec: 55.5277
# INFO:tensorflow:loss = 0.16149624, step = 15833 (2.557 sec)
# INFO:tensorflow:loss = 0.16149624, step = 15833 (2.557 sec)
# INFO:tensorflow:global_step/sec: 55.506
# INFO:tensorflow:global_step/sec: 55.506
# INFO:tensorflow:global_step/sec: 55.325
# INFO:tensorflow:global_step/sec: 55.325
# INFO:tensorflow:loss = 0.06647071, step = 15976 (2.578 sec)
# INFO:tensorflow:loss = 0.06647071, step = 15976 (2.578 sec)
# INFO:tensorflow:loss = 0.12004521, step = 16050 (6.008 sec)
# INFO:tensorflow:loss = 0.12004521, step = 16050 (6.008 sec)
# INFO:tensorflow:global_step/sec: 55.4494
# INFO:tensorflow:global_step/sec: 55.4494
# INFO:tensorflow:loss = 0.17727071, step = 16119 (2.586 sec)
# INFO:tensorflow:loss = 0.17727071, step = 16119 (2.586 sec)
# INFO:tensorflow:global_step/sec: 54.0649
# INFO:tensorflow:global_step/sec: 54.0649
# INFO:tensorflow:loss = 0.1878547, step = 16263 (2.716 sec)
# INFO:tensorflow:loss = 0.1878547, step = 16263 (2.716 sec)
# INFO:tensorflow:global_step/sec: 53.2586
# INFO:tensorflow:global_step/sec: 53.2586
# INFO:tensorflow:global_step/sec: 54.8982
# INFO:tensorflow:global_step/sec: 54.8982
# INFO:tensorflow:loss = 0.15321852, step = 16406 (2.612 sec)
# INFO:tensorflow:loss = 0.15321852, step = 16406 (2.612 sec)
# INFO:tensorflow:global_step/sec: 52.4913
# INFO:tensorflow:global_step/sec: 52.4913
# INFO:tensorflow:loss = 0.08014941, step = 16381 (6.091 sec)
# INFO:tensorflow:loss = 0.08014941, step = 16381 (6.091 sec)
# INFO:tensorflow:loss = 0.110731974, step = 16551 (2.739 sec)
# INFO:tensorflow:loss = 0.110731974, step = 16551 (2.739 sec)
# INFO:tensorflow:global_step/sec: 54.4891
# INFO:tensorflow:global_step/sec: 54.4891
# INFO:tensorflow:global_step/sec: 56.0073
# INFO:tensorflow:global_step/sec: 56.0073
# INFO:tensorflow:loss = 0.18347359, step = 16710 (6.061 sec)
# INFO:tensorflow:loss = 0.18347359, step = 16710 (6.061 sec)
# INFO:tensorflow:loss = 0.1558075, step = 16694 (2.540 sec)
# INFO:tensorflow:loss = 0.1558075, step = 16694 (2.540 sec)
# INFO:tensorflow:global_step/sec: 56.1606
# INFO:tensorflow:global_step/sec: 56.1606
# INFO:tensorflow:loss = 0.19236685, step = 16836 (2.532 sec)
# INFO:tensorflow:loss = 0.19236685, step = 16836 (2.532 sec)
# INFO:tensorflow:global_step/sec: 56.1511
# INFO:tensorflow:global_step/sec: 56.1511
# INFO:tensorflow:global_step/sec: 55.5165
# INFO:tensorflow:global_step/sec: 55.5165
# INFO:tensorflow:loss = 0.20932293, step = 16979 (2.568 sec)
# INFO:tensorflow:loss = 0.20932293, step = 16979 (2.568 sec)
# INFO:tensorflow:loss = 0.25139335, step = 17045 (5.997 sec)
# INFO:tensorflow:loss = 0.25139335, step = 17045 (5.997 sec)
# INFO:tensorflow:global_step/sec: 55.8348
# INFO:tensorflow:global_step/sec: 55.8348
# INFO:tensorflow:loss = 0.11032598, step = 17121 (2.564 sec)
# INFO:tensorflow:loss = 0.11032598, step = 17121 (2.564 sec)
# INFO:tensorflow:global_step/sec: 55.1405
# INFO:tensorflow:global_step/sec: 55.1405
# INFO:tensorflow:loss = 0.1244815, step = 17264 (2.567 sec)
# INFO:tensorflow:loss = 0.1244815, step = 17264 (2.567 sec)
# INFO:tensorflow:global_step/sec: 56.1893
# INFO:tensorflow:global_step/sec: 56.1893
# INFO:tensorflow:loss = 0.08843765, step = 17377 (5.973 sec)
# INFO:tensorflow:loss = 0.08843765, step = 17377 (5.973 sec)
# INFO:tensorflow:global_step/sec: 54.9866
# INFO:tensorflow:global_step/sec: 54.9866
# INFO:tensorflow:loss = 0.23409832, step = 17408 (2.602 sec)
# INFO:tensorflow:loss = 0.23409832, step = 17408 (2.602 sec)
# INFO:tensorflow:global_step/sec: 56.5643
# INFO:tensorflow:global_step/sec: 56.5643
# INFO:tensorflow:loss = 0.16091414, step = 17550 (2.520 sec)
# INFO:tensorflow:loss = 0.16091414, step = 17550 (2.520 sec)
# INFO:tensorflow:global_step/sec: 55.5933
# INFO:tensorflow:global_step/sec: 55.5933
# INFO:tensorflow:global_step/sec: 55.0118
# INFO:tensorflow:global_step/sec: 55.0118
# INFO:tensorflow:loss = 0.19432247, step = 17710 (5.974 sec)
# INFO:tensorflow:loss = 0.19432247, step = 17710 (5.974 sec)
# INFO:tensorflow:loss = 0.18157549, step = 17694 (2.606 sec)
# INFO:tensorflow:loss = 0.18157549, step = 17694 (2.606 sec)
# INFO:tensorflow:global_step/sec: 56.3367
# INFO:tensorflow:global_step/sec: 56.3367
# INFO:tensorflow:loss = 0.20857199, step = 17836 (2.531 sec)
# INFO:tensorflow:loss = 0.20857199, step = 17836 (2.531 sec)
# INFO:tensorflow:global_step/sec: 55.4586
# INFO:tensorflow:global_step/sec: 55.4586
# INFO:tensorflow:loss = 0.25661412, step = 17980 (2.633 sec)
# INFO:tensorflow:loss = 0.25661412, step = 17980 (2.633 sec)
# INFO:tensorflow:global_step/sec: 54.6525
# INFO:tensorflow:global_step/sec: 54.6525
# INFO:tensorflow:loss = 0.116980985, step = 18041 (5.957 sec)
# INFO:tensorflow:loss = 0.116980985, step = 18041 (5.957 sec)
# INFO:tensorflow:global_step/sec: 56.4856
# INFO:tensorflow:global_step/sec: 56.4856
# INFO:tensorflow:loss = 0.10737257, step = 18123 (2.549 sec)
# INFO:tensorflow:loss = 0.10737257, step = 18123 (2.549 sec)
# INFO:tensorflow:global_step/sec: 55.165
# INFO:tensorflow:global_step/sec: 55.165
# INFO:tensorflow:loss = 0.1567229, step = 18265 (2.540 sec)
# INFO:tensorflow:loss = 0.1567229, step = 18265 (2.540 sec)
# INFO:tensorflow:global_step/sec: 56.7536
# INFO:tensorflow:global_step/sec: 56.7536
# INFO:tensorflow:loss = 0.13262062, step = 18377 (6.002 sec)
# INFO:tensorflow:loss = 0.13262062, step = 18377 (6.002 sec)
# INFO:tensorflow:global_step/sec: 55.5056
# INFO:tensorflow:global_step/sec: 55.5056
# INFO:tensorflow:loss = 0.13207644, step = 18408 (2.547 sec)
# INFO:tensorflow:loss = 0.13207644, step = 18408 (2.547 sec)
# INFO:tensorflow:global_step/sec: 55.2047
# INFO:tensorflow:global_step/sec: 55.2047
# INFO:tensorflow:loss = 0.1825691, step = 18551 (2.587 sec)
# INFO:tensorflow:loss = 0.1825691, step = 18551 (2.587 sec)
# INFO:tensorflow:global_step/sec: 56.1065
# INFO:tensorflow:global_step/sec: 56.1065
# INFO:tensorflow:global_step/sec: 55.6898
# INFO:tensorflow:global_step/sec: 55.6898
# INFO:tensorflow:loss = 0.18053375, step = 18710 (5.990 sec)
# INFO:tensorflow:loss = 0.18053375, step = 18710 (5.990 sec)
# INFO:tensorflow:loss = 0.20474005, step = 18694 (2.552 sec)
# INFO:tensorflow:loss = 0.20474005, step = 18694 (2.552 sec)
# INFO:tensorflow:global_step/sec: 54.9314
# INFO:tensorflow:global_step/sec: 54.9314
# INFO:tensorflow:loss = 0.056925252, step = 18836 (2.590 sec)
# INFO:tensorflow:loss = 0.056925252, step = 18836 (2.590 sec)
# INFO:tensorflow:global_step/sec: 55.6173
# INFO:tensorflow:global_step/sec: 55.6173
# INFO:tensorflow:loss = 0.07043502, step = 18980 (2.569 sec)
# INFO:tensorflow:loss = 0.07043502, step = 18980 (2.569 sec)
# INFO:tensorflow:global_step/sec: 55.7183
# INFO:tensorflow:global_step/sec: 55.7183
# INFO:tensorflow:loss = 0.13779294, step = 19043 (6.007 sec)
# INFO:tensorflow:loss = 0.13779294, step = 19043 (6.007 sec)
# INFO:tensorflow:global_step/sec: 55.0505
# INFO:tensorflow:global_step/sec: 55.0505
# INFO:tensorflow:loss = 0.13264163, step = 19123 (2.596 sec)
# INFO:tensorflow:loss = 0.13264163, step = 19123 (2.596 sec)
# INFO:tensorflow:global_step/sec: 55.3971
# INFO:tensorflow:global_step/sec: 55.3971
# INFO:tensorflow:loss = 0.21202618, step = 19266 (2.585 sec)
# INFO:tensorflow:loss = 0.21202618, step = 19266 (2.585 sec)
# INFO:tensorflow:global_step/sec: 55.1293
# INFO:tensorflow:global_step/sec: 55.1293
# INFO:tensorflow:loss = 0.1459598, step = 19375 (6.011 sec)
# INFO:tensorflow:loss = 0.1459598, step = 19375 (6.011 sec)
# INFO:tensorflow:global_step/sec: 55.3966
# INFO:tensorflow:global_step/sec: 55.3966
# INFO:tensorflow:loss = 0.15791416, step = 19409 (2.591 sec)
# INFO:tensorflow:loss = 0.15791416, step = 19409 (2.591 sec)
# INFO:tensorflow:global_step/sec: 55.1524
# INFO:tensorflow:global_step/sec: 55.1524
# INFO:tensorflow:loss = 0.085677736, step = 19563 (3.293 sec)
# INFO:tensorflow:loss = 0.085677736, step = 19563 (3.293 sec)
# INFO:tensorflow:global_step/sec: 43.4908
# INFO:tensorflow:global_step/sec: 43.4908
# INFO:tensorflow:loss = 0.06134195, step = 19679 (6.038 sec)
# INFO:tensorflow:loss = 0.06134195, step = 19679 (6.038 sec)
# INFO:tensorflow:global_step/sec: 54.0407
# INFO:tensorflow:global_step/sec: 54.0407
# INFO:tensorflow:loss = 0.14648913, step = 19707 (2.651 sec)
# INFO:tensorflow:loss = 0.14648913, step = 19707 (2.651 sec)
# INFO:tensorflow:global_step/sec: 52.756
# INFO:tensorflow:global_step/sec: 52.756
# INFO:tensorflow:loss = 0.17024301, step = 19852 (2.757 sec)
# INFO:tensorflow:loss = 0.17024301, step = 19852 (2.757 sec)
# INFO:tensorflow:global_step/sec: 53.8855
# INFO:tensorflow:global_step/sec: 53.8855
# INFO:tensorflow:Saving checkpoints for 20002 into s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 20002 into s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt.
# INFO:tensorflow:global_step/sec: 54.4891
# INFO:tensorflow:global_step/sec: 54.4891
# INFO:tensorflow:loss = 0.16280782, step = 19996 (2.606 sec)
# INFO:tensorflow:loss = 0.16280782, step = 19996 (2.606 sec)
# INFO:tensorflow:Loss for final step: 0.08126964.
# INFO:tensorflow:Loss for final step: 0.08126964.
# 2021-04-22 20:40:12,685 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:115: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From mnist.py:115: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-04-22T20:40:13Z
# INFO:tensorflow:Starting evaluation at 2021-04-22T20:40:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Finished evaluation at 2021-04-22-20:40:14
# INFO:tensorflow:Finished evaluation at 2021-04-22-20:40:14
# INFO:tensorflow:Saving dict for global step 20002: accuracy = 0.9699, global_step = 20002, loss = 0.09715719
# INFO:tensorflow:Saving dict for global step 20002: accuracy = 0.9699, global_step = 20002, loss = 0.09715719
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20002: s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20002: s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Loss for final step: 0.1715225.
# INFO:tensorflow:Loss for final step: 0.1715225.
# WARNING:tensorflow:From mnist.py:184: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# WARNING:tensorflow:From mnist.py:184: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# WARNING:tensorflow:From mnist.py:145: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From mnist.py:145: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-29-39-757/model/model.ckpt-20002
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /opt/ml/model/temp-1619124015/saved_model.pb
# INFO:tensorflow:SavedModel written to: /opt/ml/model/temp-1619124015/saved_model.pb
# 2021-04-22 20:40:16,910 sagemaker-containers INFO     Reporting training SUCCESS
# 2021-04-22 20:41:31,362 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2021-04-22 20:41:31,363 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-04-22 20:41:31,363 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-04-22 20:41:49 Uploading - Uploading generated training model
# 2021-04-22 20:41:49 Completed - Training job completed
# Training seconds: 1090
# Billable seconds: 1090

# %% [markdown]
# Calling fit to train a model with TensorFlow 2.1 script.

# %%
# cell 07
mnist_estimator2.fit(training_data_uri)
# Out:
# 2021-04-22 20:50:10 Starting - Starting the training job...
# 2021-04-22 20:50:33 Starting - Launching requested ML instancesProfilerReport-1619124608: InProgress
# ......
# 2021-04-22 20:51:33 Starting - Preparing the instances for training.........
# 2021-04-22 20:53:07 Downloading - Downloading input data...
# 2021-04-22 20:53:34 Training - Downloading the training image......
# 2021-04-22 20:54:34 Training - Training image download completed. Training in progress..2021-04-22 20:54:36,121 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-04-22 20:54:36,375 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:54:36,375 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-04-22 20:54:36,375 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:54:37,273 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-04-22 20:54:38,108 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-04-22-20-50-08-617",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz",
#     "module_name": "mnist-2",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist-2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"}
# SM_USER_ENTRY_POINT=mnist-2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist-2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-04-22-20-50-08-617","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist-2.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model
#
#
# 2021-04-22 20:54:38,986 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-04-22 20:54:39,252 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:54:39,253 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-04-22 20:54:39,253 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-04-22 20:54:40,006 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-04-22 20:54:40,298 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tensorflow-training-2021-04-22-20-50-08-617",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz",
#     "module_name": "mnist-2",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist-2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"}
# SM_USER_ENTRY_POINT=mnist-2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=mnist-2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2021-04-22-20-50-08-617","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist-2.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-west-2-865118636886/tensorflow-training-2021-04-22-20-50-08-617/model
#
#
# Train on 55000 samples
# Train on 55000 samples
# #015   32/55000 [..............................] - ETA: 26:52 - loss: 2.4220 - accuracy: 0.0312#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  704/55000 [..............................] - ETA: 1:16 - loss: 1.3754 - accuracy: 0.5625 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1440/55000 [..............................] - ETA: 38s - loss: 0.9800 - accuracy: 0.6882 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2176/55000 [>.............................] - ETA: 26s - loss: 0.8126 - accuracy: 0.7422#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2912/55000 [>.............................] - ETA: 20s - loss: 0.7088 - accuracy: 0.7812#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3648/55000 [>.............................] - ETA: 16s - loss: 0.6497 - accuracy: 0.7985#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4384/55000 [=>............................] - ETA: 14s - loss: 0.6083 - accuracy: 0.8109#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5120/55000 [=>............................] - ETA: 12s - loss: 0.5677 - accuracy: 0.8242#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5856/55000 [==>...........................] - ETA: 11s - loss: 0.5425 - accuracy: 0.8321#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# #015   32/10000 [..............................] - ETA: 22s - loss: 0.0492 - accuracy: 0.9688#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  928/10000 [=>............................] - ETA: 1s - loss: 0.0952 - accuracy: 0.9698 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1920/10000 [====>.........................] - ETA: 0s - loss: 0.1276 - accuracy: 0.9604#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2880/10000 [=======>......................] - ETA: 0s - loss: 0.1312 - accuracy: 0.9583#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3840/10000 [==========>...................] - ETA: 0s - loss: 0.1287 - accuracy: 0.9586#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4800/10000 [=============>................] - ETA: 0s - loss: 0.1283 - accuracy: 0.9575#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5760/10000 [================>.............] - ETA: 0s - loss: 0.1217 - accuracy: 0.9613#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 6720/10000 [===================>..........] - ETA: 0s - loss: 0.1189 - accuracy: 0.9628#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 7712/10000 [======================>.......] - ETA: 0s - loss: 0.1077 - accuracy: 0.9665#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# 2021-04-22 20:54:48.303742: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# 2021-04-22 20:54:49,071 sagemaker-containers INFO     Reporting training SUCCESS
# #015   32/55000 [..............................] - ETA: 29:25 - loss: 2.4238 - accuracy: 0.0625#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  704/55000 [..............................] - ETA: 1:23 - loss: 1.3037 - accuracy: 0.5923 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1408/55000 [..............................] - ETA: 43s - loss: 0.9325 - accuracy: 0.7109 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2112/55000 [>.............................] - ETA: 29s - loss: 0.7947 - accuracy: 0.7580#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2784/55000 [>.............................] - ETA: 23s - loss: 0.6972 - accuracy: 0.7859#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3488/55000 [>.............................] - ETA: 18s - loss: 0.6293 - accuracy: 0.8096#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4192/55000 [=>............................] - ETA: 16s - loss: 0.5859 - accuracy: 0.8242#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4864/55000 [=>............................] - ETA: 14s - loss: 0.5601 - accuracy: 0.8331#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5568/55000 [==>...........................] - ETA: 12s - loss: 0.5386 - accuracy: 0.8387#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# #015   32/10000 [..............................] - ETA: 25s - loss: 0.0202 - accuracy: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  960/10000 [=>............................] - ETA: 1s - loss: 0.1101 - accuracy: 0.9656 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1888/10000 [====>.........................] - ETA: 0s - loss: 0.1383 - accuracy: 0.9592#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2816/10000 [=======>......................] - ETA: 0s - loss: 0.1453 - accuracy: 0.9570#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3744/10000 [==========>...................] - ETA: 0s - loss: 0.1355 - accuracy: 0.9607#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4640/10000 [============>.................] - ETA: 0s - loss: 0.1417 - accuracy: 0.9571#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5536/10000 [===============>..............] - ETA: 0s - loss: 0.1323 - accuracy: 0.9601#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 6432/10000 [==================>...........] - ETA: 0s - loss: 0.1285 - accuracy: 0.9611#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 7360/10000 [=====================>........] - ETA: 0s - loss: 0.1210 - accuracy: 0.9632#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
#
# 2021-04-22 20:57:13 Uploading - Uploading generated training model
# 2021-04-22 20:57:13 Completed - Training job completed
# 2021-04-22 20:57:00,704 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2021-04-22 20:57:00,704 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-04-22 20:57:00,704 sagemaker-containers INFO     Reporting training SUCCESS
# Training seconds: 492
# Billable seconds: 492

# %% [markdown]
# # Deploy the trained model to an endpoint
# The `deploy()` method creates a SageMaker model, which is then deployed to an endpoint to serve prediction requests in real time. We will use the TensorFlow Serving container for the endpoint, because we trained with script mode. This serving container runs an implementation of a web server that is compatible with SageMaker hosting protocol. The [Using your own inference code](https://render.githubusercontent.com/view/ipynb?color_mode=auto&commit=a5c9a21e6ed70fd51ab5178f3a35461473f7b379&enc_url=...&nwo=aws%2Famazon-sagemaker-examples&path=sagemaker-python-sdk%2Ftensorflow_script_mode_training_and_serving%2Ftensorflow_script_mode_training_and_serving.ipynb&repository_id=107937815&repository_type=Repository) document explains how SageMaker runs inference containers.

# %%
# cell 08
predictor = mnist_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# -------------!

# %% [markdown]
# Deployed the trained TensorFlow 2.1 model to an endpoint.

# %%
# cell 09
predictor2 = mnist_estimator2.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# -------------!

# %% [markdown]
# # Invoke the endpoint
# Let's download the training data and use that as input for inference.

# %%
# cell 10
import numpy as np

# !aws --region {region} s3 cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_data.npy train_data.npy
# !aws --region {region} s3 cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_labels.npy train_labels.npy

train_data = np.load('train_data.npy')
train_labels = np.load('train_labels.npy')
# Out:
# download: s3://sagemaker-sample-data-us-west-2/tensorflow/mnist/train_data.npy to ./train_data.npy
# download: s3://sagemaker-sample-data-us-west-2/tensorflow/mnist/train_labels.npy to ./train_labels.npy

# %% [markdown]
# The formats of the input and the output data correspond directly to the request and response formats of the Predict method in the [TensorFlow Serving REST API](https://www.tensorflow.org/serving/api_rest). SageMaker's TensforFlow Serving endpoints can also accept additional input formats that are not part of the TensorFlow REST API, including the simplified JSON format, line-delimited JSON objects ("jsons" or "jsonlines"), and CSV data.
#
# In this example we are using a numpy array as input, which will be serialized into the simplified JSON format. In addtion, TensorFlow serving can also process multiple items at once as you can see in the following code. You can find the complete documentation on how to make predictions against a TensorFlow serving SageMaker endpoint [here](https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/deploying_tensorflow_serving.rst#making-predictions-against-a-sagemaker-endpoint).

# %%
# cell 11
predictions = predictor.predict(train_data[:50])
for i in range(0, 50):
    prediction = predictions['predictions'][i]['classes']
    label = train_labels[i]
    print('prediction is {}, label is {}, matched: {}'.format(prediction, label, prediction == label))
# Out:
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 8, matched: False
# prediction is 8, label is 8, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 7, label is 7, matched: True

# %% [markdown]
# Examine the prediction result from the TensorFlow 2.1 model.

# %%
# cell 12
predictions2 = predictor2.predict(train_data[:50])
for i in range(0, 50):
    prediction = np.argmax(predictions2['predictions'][i])
    label = train_labels[i]
    print('prediction is {}, label is {}, matched: {}'.format(prediction, label, prediction == label))
# Out:
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 9, label is 4, matched: False
# prediction is 6, label is 6, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 7, label is 7, matched: True

# %% [markdown]
# # Delete the endpoint
# Let's delete the endpoint we just created to prevent incurring any extra costs and then [verify](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html)

# %%
# cell 13
predictor.delete_endpoint()

# %%
# cell 14
predictor2.delete_endpoint()
