# %%
# !pip install --upgrade pip
# !pip install -r local-requirements.txt

# make sure updates to the python modules are imported
# %load_ext autoreload
# %autoreload 2

# %%
from sagemaker.s3 import S3Uploader
import sagemaker

# Upload the data from the local dataset folder to the default bucket
output_bucket = sagemaker.Session().default_bucket()

local_data_file = "../datasets/template.json"
data_s3_location = f"s3://{output_bucket}/llm-evaluation-at-scale-example"
training_s3_location = f"{data_s3_location}/train_dataset"
validation_s3_location = f"{data_s3_location}/val_dataset"

print(f"Default data location: {data_s3_location}")
print(f"Default train location: {training_s3_location}")
print(f"Default data location: {validation_s3_location}")

S3Uploader.upload("../datasets/evaluation_dataset_trivia.jsonl", data_s3_location)
S3Uploader.upload("../datasets/train_dataset_trivia.jsonl", training_s3_location)
S3Uploader.upload("../datasets/template.json", training_s3_location)
S3Uploader.upload("../datasets/validation_dataset.jsonl", validation_s3_location)
S3Uploader.upload("../datasets/template.json", validation_s3_location)

# %%
# !python pipeline_scale_advanced.py --config pipeline_config.yaml

# %%
# !python pipeline_scale_advanced.py --config pipeline_scale_config.yaml
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Fetched defaults config from location: /root/fm-eval-at-scale/fm-evaluation-pipeline/src/sm_pipelines
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Fetched defaults config from location: /root/fm-eval-at-scale/fm-evaluation-pipeline/src/sm_pipelines
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Fetched defaults config from location: /root/fm-eval-at-scale/fm-evaluation-pipeline/src/sm_pipelines
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:04,115 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:04,187 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:04,507 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp8fmyzd1g/requirements.txt'
# 2023-11-07 17:29:04,573 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# 2023-11-07 17:29:04,631 sagemaker.remote_function INFO     Copied user workspace '/root/fm-eval-at-scale/fm-evaluation-pipeline/src/sm_pipelines' to '/tmp/tmpko6cww5f/temp_workspace/sagemaker_remote_function_workspace'
# 2023-11-07 17:29:04,698 sagemaker.remote_function INFO     Successfully created workdir archive at '/tmp/tmpko6cww5f/workspace.zip'
# 2023-11-07 17:29:04,926 sagemaker.remote_function INFO     Successfully uploaded workdir to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/sm_rf_user_ws/2023-11-07-17-29-01-731/workspace.zip'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:07,359 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:07,435 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:07,522 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp7p5re5vr/requirements.txt'
# 2023-11-07 17:29:07,552 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:10,196 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:10,279 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:10,392 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpwz03lykw/requirements.txt'
# 2023-11-07 17:29:10,450 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:12,937 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:13,006 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:13,102 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmps41qowmz/requirements.txt'
# 2023-11-07 17:29:13,134 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:15,593 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:15,661 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:15,834 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpwdd8mxwi/requirements.txt'
# 2023-11-07 17:29:15,892 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:18,173 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:18,273 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:18,376 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp6ubqddf7/requirements.txt'
# 2023-11-07 17:29:18,453 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:20,990 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:21,060 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:21,119 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp6yqhu7gt/requirements.txt'
# 2023-11-07 17:29:21,155 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:23,639 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:23,702 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:23,797 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpr9hheshl/requirements.txt'
# 2023-11-07 17:29:23,846 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:26,291 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:26,388 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:26,486 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpe59pnhm8/requirements.txt'
# 2023-11-07 17:29:26,523 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:28,680 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:28,807 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:28,944 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpu51oj6xh/requirements.txt'
# 2023-11-07 17:29:28,973 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:31,709 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:31,780 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:31,897 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpc9qws7cd/requirements.txt'
# 2023-11-07 17:29:31,930 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.Dependencies
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.WorkdirConfig.IgnoreNamePatterns
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.InstanceType
# sagemaker.config INFO - Applied value from config key = SageMaker.PythonSDK.Modules.RemoteFunction.RoleArn
# 2023-11-07 17:29:35,289 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-01-731/function
# 2023-11-07 17:29:35,394 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-01-731/arguments
# 2023-11-07 17:29:35,474 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp4ys0bdd7/requirements.txt'
# 2023-11-07 17:29:35,506 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-01-731/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:36,281 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:36,355 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:36,743 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpt_8cbhas/requirements.txt'
# 2023-11-07 17:29:36,776 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/model_selection/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# 2023-11-07 17:29:36,826 sagemaker.remote_function INFO     Copied user workspace '/root/fm-eval-at-scale/fm-evaluation-pipeline/src/sm_pipelines' to '/tmp/tmpslu2ue2z/temp_workspace/sagemaker_remote_function_workspace'
# 2023-11-07 17:29:36,894 sagemaker.remote_function INFO     Successfully created workdir archive at '/tmp/tmpslu2ue2z/workspace.zip'
# 2023-11-07 17:29:37,020 sagemaker.remote_function INFO     Successfully uploaded workdir to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/sm_rf_user_ws/2023-11-07-17-29-36-281/workspace.zip'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:37,022 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:37,168 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:37,236 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpmbf9er7n/requirements.txt'
# 2023-11-07 17:29:37,276 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:37,277 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:37,345 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:37,469 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpf3h2glop/requirements.txt'
# 2023-11-07 17:29:37,495 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:37,496 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:37,557 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:37,697 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpa3m0nrxw/requirements.txt'
# 2023-11-07 17:29:37,722 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b-f-2/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:37,723 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:37,796 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:37,932 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp4w9mb0s3/requirements.txt'
# 2023-11-07 17:29:37,959 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_falcon-7b-2/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:37,960 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:38,094 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:38,336 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmp498hcihu/requirements.txt'
# 2023-11-07 17:29:38,364 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/evaluation_llama2-7b/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:38,365 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:38,483 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:38,596 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmps5oziky_/requirements.txt'
# 2023-11-07 17:29:38,627 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/preprocess/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:38,634 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:38,732 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:38,816 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpa_0rhtza/requirements.txt'
# 2023-11-07 17:29:38,847 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:38,848 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:38,931 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:39,052 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpjngzyefs/requirements.txt'
# 2023-11-07 17:29:39,077 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:39,078 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:39,136 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:39,217 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpldcbsjn1/requirements.txt'
# 2023-11-07 17:29:39,263 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b-f-2/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:39,264 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:39,414 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:39,514 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmphc2pxef_/requirements.txt'
# 2023-11-07 17:29:39,548 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_falcon-7b-2/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.
# 2023-11-07 17:29:39,549 sagemaker.remote_function INFO     Serializing function code to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-36-281/function
# 2023-11-07 17:29:39,695 sagemaker.remote_function INFO     Serializing function arguments to s3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-36-281/arguments
# 2023-11-07 17:29:39,775 sagemaker.remote_function INFO     Copied dependencies file at './requirements.txt' to '/tmp/tmpjsgtl44q/requirements.txt'
# 2023-11-07 17:29:39,805 sagemaker.remote_function INFO     Successfully uploaded dependencies and pre execution scripts to 's3://sagemaker-us-east-1-679056704839/llm-evaluation-multi-models/deploy_llama2-7b/2023-11-07-17-29-36-281/pre_exec_script_and_dependencies'
# WARNING:sagemaker.workflow.utilities:Popping out 'TrainingJobName' from the pipeline definition by default since it will be overridden at pipeline execution time. Please utilize the PipelineDefinitionConfig to persist this field in the pipeline definition if desired.

# %%
# !python pipeline_scale_advanced.py --config pipeline_finetuning_config.yaml

# %%
# !python pipeline_scale_advanced.py --config pipeline_scale_hybrid_config.yaml
