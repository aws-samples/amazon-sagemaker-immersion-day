# %% [markdown]
# <div style="border: 2px solid #ff9900; border-radius: 8px; padding: 15px; background-color: #fff3e0; margin-bottom: 10px;">
# <strong>⚠️ Compatibility Notice:</strong> This notebook has been tested using <strong>SageMaker Distribution Image 3.7.0</strong> and the <strong>SageMaker Python SDK version 3.4.0</strong>.
# </div>

# %%
# !pip install -q -U "sagemaker==3.4.0"

# %%
# Restart kernel to pick up the updated packages
import IPython
IPython.Application.instance().kernel.do_shutdown(True)

# %% [markdown]
# # Finetune a stable diffusion model for text to image generation

# %% [markdown]
# ***
# Welcome to Amazon [SageMaker JumpStart](https://docs.aws.amazon.com/sagemaker/latest/dg/studio-jumpstart.html)! You can use JumpStart to solve many Machine Learning tasks through one-click in SageMaker Studio, or through [SageMaker JumpStart API](https://sagemaker.readthedocs.io/en/stable/overview.html#use-prebuilt-models-with-sagemaker-jumpstart).  In this demo notebook, we demonstrate how to use the JumpStart API to generate images from text using state-of-the-art Stable Diffusion models. Furthermore, we show how to fine-tune the model to your dataset.
#
# Stable Diffusion is a text-to-image model that enables you to create photorealistic images from just a text prompt. A diffusion model trains by learning to remove noise that was added to a real image. This de-noising process generates a realistic image. These models can also generate images from text alone by conditioning the generation process on the text. For instance, Stable Diffusion is a latent diffusion where the model learns to recognize shapes in a pure noise image and gradually brings these shapes into focus if the shapes match the words in the input text.
#
# Training and deploying large models and running inference on models such as Stable Diffusion is often challenging and include issues such as cuda out of memory, payload size limit exceeded and so on.  JumpStart simplifies this process by providing ready-to-use scripts that have been robustly tested. Furthermore, it provides guidance on each step of the process including the recommended instance types, how to select parameters to guide image generation process, prompt engineering etc. Moreover, you can deploy and run inference on any of the 80+ Diffusion models from JumpStart without having to write any piece of your own code.
#
#
# In his notebook, you will learn how to use JumpStart to fine-tune the Stable Diffusion model to your dataset. This can be useful when creating art, logos, custom designs, NFTs, and so on, or fun stuff such as generating custom AI images of your pets or avatars of yourself.
#
#
# Model lincese: By using this model, you agree to the [CreativeML Open RAIL-M++ license](https://huggingface.co/stabilityai/stable-diffusion-2/blob/main/LICENSE-MODEL).
#
# ***

# %% [markdown]
# 1. [Set Up](#1.-Set-Up)
# 2. [Fine-tune the pre-trained model on a custom dataset](#2.-Fine-tune-the-pre-trained-model-on-a-custom-dataset)
#     * [Retrieve Training Artifacts](#2.1.-Retrieve-Training-Artifacts)
#     * [Set Training parameters](#2.2.-Set-Training-parameters)
#     * [Start Training](#2.3.-Start-Training)
#     * [Deploy and run inference on the fine-tuned model](#3.2.-Deploy-and-run-inference-on-the-fine-tuned-model)
# 3. [Conclusion](#3.-Conclusion)

# %% [markdown]
# Note: This notebook was tested on ml.t3.medium instance in Amazon SageMaker Studio with Python 3 (Data Science) kernel and in Amazon SageMaker Notebook instance with conda_python3 kernel.
#
# Note: For fine-tuning the model on your dataset, you need `ml.g4dn.2xlarge` instance type available in your account. To deploy the fine-trained model, you can use `ml.g5.2xlarge` or `ml.g4dn.2xlarge` instance types. We recommend using `ml.g5.2xlarge` for deployment.

# %% [markdown]
# ## 1. Set Up

# %% [markdown]
# ***
# Before executing the notebook, there are some initial steps required for set up. This notebook requires latest version of sagemaker.
#
# ***

# %% [markdown]
# #### Permissions and environment variables
#
# ***
# To host on Amazon SageMaker, we need to set up and authenticate the use of AWS services. Here, we use the execution role associated with the current notebook as the AWS account role with SageMaker access.
#
# ***

# %%
import os, json, boto3
from sagemaker.core.helper.session_helper import Session, get_execution_role

aws_role = get_execution_role()
aws_region = boto3.Session().region_name
sagemaker_session = Session()

# %% [markdown]
# ## 2. Fine-tune the pre-trained model on a custom dataset
#
# ---
# Previously, we saw how to run inference on a pre-trained model. Next, we discuss how a model can be finetuned to a custom dataset with any number of classes.
#
# The model can be fine-tuned to any dataset of images. It works very well even with as little as five training images.
#
# The fine-tuning script is built on the script from [dreambooth](https://dreambooth.github.io/). The model returned by fine-tuning can be further deployed for inference. Below are the instructions for how the training data should be formatted.
#
# - **Input:** A directory containing the instance images, `dataset_info.json` and (optional) directory `class_data_dir`.
#   - Images may be of `.png` or `.jpg` or `.jpeg` format.
#   - `dataset_info.json` file must be of the format {'instance_prompt':<<instance_prompt>>,'class_prompt':<<class_prompt>>}.
#   - If with_prior_preservation = False, you may choose to ignore 'class_prompt'.
#   - `class_data_dir` directory must have class images. If with_prior_preservation = True and class_data_dir is not present or there are not enough images already present in class_data_dir, additional images will be sampled with class_prompt.
# - **Output:** A trained model that can be deployed for inference.
#
# The s3 path should look like `s3://bucket_name/input_directory/`. Note the trailing `/` is required.
#
# Here is an example format of the training data.
#
#     input_directory
#         |---instance_image_1.png
#         |---instance_image_2.png
#         |---instance_image_3.png
#         |---instance_image_4.png
#         |---instance_image_5.png
#         |---dataset_info.json
#         |---class_data_dir
#             |---class_image_1.png
#             |---class_image_2.png
#             |---class_image_3.png
#             |---class_image_4.png
#
# **Prior preservation, instance prompt and class prompt:** Prior preservation is a technique that uses additional images of the same class that we are trying to train on.  For instance, if the training data consists of images of a particular dog, with prior preservation, we incorporate class images of generic dogs. It tries to avoid overfitting by showing images of different dogs while training for a particular dog. Tag indicating the specific dog present in instance prompt is missing in the class prompt. For instance, instance prompt may be "a photo of a Doppler dog" and class prompt may be "a photo of a dog". You can enable prior preservation by setting the hyper-parameter with_prior_preservation = True.
#
#
#
# We provide a default dataset of dog images. It consists of images (instance images corresponding to instance prompt) of a single dog with no class images. If using the default dataset, try the prompt "a photo of a Doppler dog" while doing inference in the demo notebook.
#
#
# License: [MIT](https://github.com/marshmellow77/dreambooth-sm/blob/main/LICENSE).

# %% [markdown]
# ### 2.1. Retrieve Training Artifacts
#
# ---
# Here, we retrieve the training docker container, the training algorithm source, and the pre-trained base model. Note that model_version="*" fetches the latest model.
#
# ---

# %%
from sagemaker.core.jumpstart.configs import JumpStartConfig
from sagemaker.train.model_trainer import ModelTrainer

train_model_id = "model-txt2img-stabilityai-stable-diffusion-v2-1-base"
training_instance_type = "ml.g5.2xlarge"

jumpstart_config = JumpStartConfig(model_id=train_model_id)

# %% [markdown]
# ### 2.2. Set Training parameters
#
# ---
# Now that we are done with all the set up that is needed, we are ready to train our stable diffusion model. To begin, let us create a [``sageMaker.estimator.Estimator``](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html) object. This estimator will launch the training job.
#
# There are two kinds of parameters that need to be set for training. The first one are the parameters for the training job. These include: (i) Training data path. This is S3 folder in which the input data is stored, (ii) Output path: This the s3 folder in which the training output is stored. (iii) Training instance type: This indicates the type of machine on which to run the training. We defined the training instance type above to fetch the correct train_image_uri.
#
# The second set of parameters are algorithm specific training hyper-parameters.
#
# ---

# %%
training_data_bucket = f"jumpstart-cache-prod-{aws_region}"
training_data_prefix = "training-datasets/dogs_sd_finetuning/"
training_dataset_s3_path = f"s3://{training_data_bucket}/{training_data_prefix}"

output_bucket = sagemaker_session.default_bucket()
output_prefix = "jumpstart-example-sd-training"
s3_output_location = f"s3://{output_bucket}/{output_prefix}/output"

# %% [markdown]
# ---
# For algorithm specific hyper-parameters, we start by fetching python dictionary of the training hyper-parameters that the algorithm accepts with their default values. This can then be overridden to custom values.
#
# ---

# %%
# Override default hyperparameters
custom_hyperparameters = {
    "max_steps": "400",
    "with_prior_preservation": "True",
}
print(custom_hyperparameters)
# Out:
# {'max_steps': '400', 'with_prior_preservation': 'True'}

# %% [markdown]
# ---
# If setting `with_prior_preservation=True`, please use ml.g5.2xlarge instance type as more memory is required to generate class images. Currently, training on ml.g4dn.2xlarge instance type run into CUDA out of memory issue when setting `with_prior_preservation=True`.
#
# ---

# %% [markdown]
# #### Download the dataset used for training from remote training location to local and take a look at it
# You will find the downloaded dataset in a new folder called `training-datasets` in the directory that you are currently at, after executing the next code block

# %%
s3_resource = boto3.resource('s3')
bucket = s3_resource.Bucket(training_data_bucket) 
for obj in bucket.objects.filter(Prefix = training_data_prefix):
    if not os.path.exists(os.path.dirname(obj.key)):
        os.makedirs(os.path.dirname(obj.key))
    bucket.download_file(obj.key, obj.key) # save to same path

# %% [markdown]
# ### 2.3. Start Training
# ---
# We start by creating the estimator object with all the required assets and then launch the training job.  It takes less than 10 mins on the default dataset.
#
# ---

# %%
from sagemaker.core.training.configs import Compute, InputData
from sagemaker.core.shapes import OutputDataConfig
from sagemaker.core.common_utils import unique_name_from_base

training_job_name = unique_name_from_base(f"jumpstart-sd-v2-1-finetune")

model_trainer = ModelTrainer.from_jumpstart_config(
    jumpstart_config=jumpstart_config,
    base_job_name=training_job_name,
    hyperparameters=custom_hyperparameters,
    compute=Compute(instance_type=training_instance_type, instance_count=1),
    output_data_config=OutputDataConfig(s3_output_path=s3_output_location),
    sagemaker_session=sagemaker_session,
)

train_input = InputData(channel_name="training", data_source=training_dataset_s3_path)
print(f"Starting training: {training_job_name}")
model_trainer.train(input_data_config=[train_input])
print("Training completed!")
# Out:
# [02/11/26 11:12:33] INFO     Role not provided. Using default role:                                  ]8;id=67949;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=897926;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#75\75]8;;\
#                              arn:aws:iam::975049911976:role/from-idea-to-prod-SageMakerExecutionRole
#                              -h5rrBhGSjbNO
#                     INFO     Runs on sagemaker prod, region:us-west-2                                  ]8;id=470782;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py\utils.py]8;;\:]8;id=407478;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py#354\354]8;;\
# [02/11/26 11:12:34] INFO     hub_content_name: model-txt2img-stabilityai-stable-diffusion-v2-1-base, ]8;id=185646;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/jumpstart/document.py\document.py]8;;\:]8;id=575273;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/jumpstart/document.py#71\71]8;;\
#                              hub_content_version: 2.0.17
#                     INFO     Networking not provided. Using default networking:                     ]8;id=179801;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=626680;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#265\265]8;;\
#                              security_group_ids=None subnets=None enable_network_isolation=True
#                              enable_inter_container_traffic_encryption=None
#                     INFO     Training image not provided. Using default:                            ]8;id=507530;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=669045;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#297\297]8;;\
#                              763104351884.dkr.ecr.us-west-2.amazonaws.com/huggingface-pytorch-train
#                              ing:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04
#                     WARNING  Using default training dataset. To override, provide custom input data ]8;id=958290;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=55673;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#452\452]8;;\
#                              to the 'training' or 'train' input channel.
#                     INFO     Using default training dataset: channel_name='training'                ]8;id=577509;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=608600;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#469\469]8;;\
#                              data_source=S3DataSource(s3_data_type='S3Prefix',
#                              s3_uri='s3://jumpstart-cache-prod-us-west-2/training-datasets/cats_sd_
#                              finetuning/', s3_data_distribution_type='FullyReplicated',
#                              attribute_names=None,
#                              instance_group_names=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0>,
#                              model_access_config=ModelAccessConfig(accept_eula=False),
#                              hub_access_config=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0>) content_type=None
#                     INFO     Using default model artifact: channel_name='model'                     ]8;id=895970;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=376285;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#558\558]8;;\
#                              data_source=DataSource(s3_data_source=S3DataSource(s3_data_type='S3Pre
#                              fix',
#                              s3_uri='s3://jumpstart-cache-prod-us-west-2/stabilityai-training/train
#                              -model-txt2img-stabilityai-stable-diffusion-v2-1-base.tar.gz',
#                              s3_data_distribution_type='FullyReplicated', attribute_names=None,
#                              instance_group_names=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0>,
#                              model_access_config=ModelAccessConfig(accept_eula=False),
#                              hub_access_config=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0>),
#                              file_system_data_source=<sagemaker.core.utils.utils.Unassigned object
#                              at 0x7f6c6484a7b0>,
#                              dataset_source=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0>) content_type='application/x-sagemaker-model'
#                              compression_type='None'
#                              record_wrapper_type=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0> input_mode='File'
#                              shuffle_config=<sagemaker.core.utils.utils.Unassigned object at
#                              0x7f6c6484a7b0> enable_ffm=<sagemaker.core.utils.utils.Unassigned
#                              object at 0x7f6c6484a7b0>
#                     INFO     Adding JumpStart Tags:                                                 ]8;id=414225;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=336596;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#629\629]8;;\
#                              key='sagemaker-sdk:jumpstart-model-id'
#                              value='model-txt2img-stabilityai-stable-diffusion-v2-1-base',
#                              key='sagemaker-sdk:jumpstart-model-version' value='2.0.17'
#                     INFO     StoppingCondition not provided. Using default:                         ]8;id=265969;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py\defaults.py]8;;\:]8;id=895886;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/defaults.py#125\125]8;;\
#                              max_runtime_in_seconds=3600 max_wait_time_in_seconds=None
#                              max_pending_time_in_seconds=None
#                     INFO     Training image URI:                                               ]8;id=472075;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/model_trainer.py\model_trainer.py]8;;\:]8;id=890073;file:///opt/conda/lib/python3.12/site-packages/sagemaker/train/model_trainer.py#548\548]8;;\
#                              763104351884.dkr.ecr.us-west-2.amazonaws.com/huggingface-pytorch-
#                              training:1.10.2-transformers4.17.0-gpu-py38-cu113-ubuntu20.04
# Starting training: jumpstart-sd-v2-1-finetune-1770808353-bcb3
#                     INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=441024;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=246638;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/telemetry/telemetry_logging.py#92\92]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
#                     INFO     Creating training_job resource.                                     ]8;id=862598;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=237341;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35539\35539]8;;\
# /opt/conda/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# [02/11/26 11:19:24] INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=580201;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=346944;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Starting training script
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=124597;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=387472;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ /opt/conda/bin/python3 --version
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=291192;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=494427;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Python 3.8.13
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=32109;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=739537;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo /opt/ml/input/config/resourceconfig.json:
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=760363;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=418619;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              /opt/ml/input/config/resourceconfig.json:
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=874883;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=977271;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ cat /opt/ml/input/config/resourceconfig.json
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=274454;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=999950;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=725201;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=62769;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo /opt/ml/input/config/inputdataconfig.json:
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=390153;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=510567;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              {"current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","c
#                              urrent_group_name":"homogeneousCluster","hosts":["algo-1"],"instanc
#                              e_groups":[{"instance_group_name":"homogeneousCluster","instance_ty
#                              pe":"ml.p3.2xlarge","hosts":["algo-1"]}],"network_interface_name":"
#                              eth0","topology":null}
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=658372;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=492838;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              /opt/ml/input/config/inputdataconfig.json:
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=412116;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=628373;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ cat /opt/ml/input/config/inputdataconfig.json
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=898433;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=969458;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=58073;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=963698;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo 'Setting up environment variables'
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=734403;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=15621;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ /opt/conda/bin/python3
#                              /opt/ml/input/data/sm_drivers/scripts/environment.py
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=846260;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=590859;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              {"code":{"TrainingInputMode":"File","S3DistributionType":"FullyRepl
#                              icated","RecordWrapperType":"None"},"model":{"ContentType":"applica
#                              tion/x-sagemaker-model","TrainingInputMode":"File","S3DistributionT
#                              ype":"FullyReplicated","RecordWrapperType":"None"},"sm_drivers":{"T
#                              rainingInputMode":"File","S3DistributionType":"FullyReplicated","Re
#                              cordWrapperType":"None"},"training":{"TrainingInputMode":"File","S3
#                              DistributionType":"FullyReplicated","RecordWrapperType":"None"}}
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=725864;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=264832;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Setting up environment variables
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=75277;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=623293;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              No Neurons detected (normal if no neurons installed)
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=384118;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=98348;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Environment Variables:
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=616284;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=131150;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NVIDIA_VISIBLE_DEVICES=all
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=12189;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=687242;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              PYTHONUNBUFFERED=1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=642998;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=301162;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SAGEMAKER_TRAINING_MODULE=sagemaker_pytorch_container.training:main
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=280101;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=136967;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              HOSTNAME=algo-1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=346471;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=102271;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NVIDIA_REQUIRE_CUDA=cuda>=11.3 brand=tesla,driver>=418,driver<419
#                              driver>=450
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=600445;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=584284;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              MANUAL_BUILD=0
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=504281;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=149048;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              BRANCH_OFI=1.2.0-aws
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=257602;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=4420;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              TORCH_NVCC_FLAGS=-Xfatbin -compress-all
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=153546;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=935158;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              TORCH_CUDA_ARCH_LIST=3.7 5.0 7.0+PTX 8.0
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=580004;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=586865;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NCCL_VERSION=2.10.3
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=836649;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=628297;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              AWS_REGION=us-west-2
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=265431;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=352896;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              PWD=/
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=118517;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=259596;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              RDMAV_FORK_SAFE=1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=964132;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=23347;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY=/opt/ml/sagemaker/warmpo
#                              olcache
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=420663;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=964022;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NVIDIA_DRIVER_CAPABILITIES=compute,utility,compat32,graphics,video
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=974770;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=700675;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              HOROVOD_VERSION=0.25.0
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=972170;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=611106;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NV_CUDA_CUDART_VERSION=11.3.109-1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=413101;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=593326;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              HOME=/root
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=27648;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=44383;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              LANG=C.UTF-8
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=150810;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=754730;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              CUDA_VERSION=11.3.1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=471722;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=664859;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              DMLC_INTERFACE=eth0
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=44026;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=225299;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              CMAKE_PREFIX_PATH=$(dirname $(which conda))/../
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=903388;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=793508;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_LOG_LEVEL=20
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=580508;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=876392;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              PYTHONIOENCODING=UTF-8
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=791375;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=416700;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SHLVL=1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=37065;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=100012;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NVARCH=x86_64
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=700463;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=336065;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              CUDNN_VERSION=8.2.0.53
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=333233;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=609;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              EFA_VERSION=1.15.2
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=245565;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=81103;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              PYTHONDONTWRITEBYTECODE=1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=145299;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=230362;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              NV_CUDA_COMPAT_PACKAGE=cuda-compat-11-3
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=215124;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=470807;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              LD_LIBRARY_PATH=/opt/conda/lib/python3.8/site-packages/smdistribute
#                              d/dataparallel/lib:/opt/amazon/openmpi/lib/:/opt/amazon/efa/lib/:/o
#                              pt/conda/lib:/usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia
#                              /lib64:/usr/local/lib
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=785866;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=952952;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              OMPI_VERSION=4.1.1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=376776;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=542496;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              TRAINING_JOB_NAME=jumpstart-sd-v2-1-finetune-1770808353-bcb3-202602
#                              11111234
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=881452;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=242277;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              LC_ALL=C.UTF-8
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=329615;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=48491;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              TRAINING_JOB_ARN=arn:aws:sagemaker:us-west-2:975049911976:training-
#                              job/jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=771035;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=578877;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              PATH=/opt/amazon/openmpi/bin:/opt/conda/bin:/usr/local/nvidia/bin:/
#                              usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bi
#                              n:/sbin:/bin
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=64128;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=64371;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              DEBIAN_FRONTEND=noninteractive
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=238268;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=645670;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              DLC_CONTAINER_TYPE=training
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=491952;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=681925;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              _=/opt/conda/bin/python3
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=903642;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=405258;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_MODEL_DIR=/opt/ml/model
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=461470;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=131270;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_INPUT_DIR=/opt/ml/input
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=249375;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=431065;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_INPUT_DATA_DIR=/opt/ml/input/data
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=918219;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=11456;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_INPUT_CONFIG_DIR=/opt/ml/input/config
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=776025;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=258328;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_OUTPUT_DIR=/opt/ml/output
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=955073;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=492278;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_OUTPUT_FAILURE=/opt/ml/output/failure
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=80399;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=626072;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_OUTPUT_DATA_DIR=/opt/ml/output/data
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=124552;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=369340;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_LOG_LEVEL=20
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=441529;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=276450;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_MASTER_ADDR=algo-1
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=839488;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=608214;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_MASTER_PORT=7777
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=546277;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=536750;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_SOURCE_DIR=/opt/ml/input/data/code
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=240552;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=970186;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_ENTRY_SCRIPT=transfer_learning.py
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=264231;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=342014;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_CHANNEL_CODE=/opt/ml/input/data/code
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=296422;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=318049;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_CHANNEL_MODEL=/opt/ml/input/data/model
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=597909;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=563487;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_CHANNEL_SM_DRIVERS=/opt/ml/input/data/sm_drivers
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=276589;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=129946;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_CHANNEL_TRAINING=/opt/ml/input/data/training
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=540754;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=902017;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              SM_CHANNELS=['code', 'model', 'sm_drivers', 'training']
# ...
#                              lr=2e-6] #015Steps:  92%|█████████▎| 370/400 [04:57<00:24,
#                              1.25it/s, loss=0.108, lr=2e-6]#015Steps:  92%|█████████▎| 370/400
#                              [04:57<00:24,  1.25it/s, loss=0.451, lr=2e-6]#015Steps:
#                              93%|█████████▎| 371/400 [04:58<00:23,  1.25it/s, loss=0.451,
#                              lr=2e-6]#015Steps:  93%|█████████▎| 371/400 [04:58<00:23,
#                              1.25it/s, loss=0.0822, lr=2e-6]#015Steps:  93%|█████████▎| 372/400
#                              [04:58<00:22,  1.25it/s, loss=0.0822, lr=2e-6]#015Steps:
#                              93%|█████████▎| 372/400 [04:58<00:22,  1.25it/s, loss=0.131,
#                              lr=2e-6] #015Steps:  93%|█████████▎| 373/400 [04:59<00:21,
#                              1.24it/s, loss=0.131, lr=2e-6]#015Steps:  93%|█████████▎| 373/400
#                              [04:59<00:21,  1.24it/s, loss=0.102, lr=2e-6]#015Steps:
#                              94%|█████████▎| 374/400 [05:00<00:20,  1.25it/s, loss=0.102,
#                              lr=2e-6]#015Steps:  94%|█████████▎| 374/400 [05:00<00:20,
#                              1.25it/s, loss=0.163, lr=2e-6]#015Steps:  94%|█████████▍| 375/400
#                              [05:01<00:20,  1.25it/s, loss=0.163, lr=2e-6]#015Steps:
#                              94%|█████████▍| 375/400 [05:01<00:20,  1.25it/s, loss=0.0763,
#                              lr=2e-6]#015Steps:  94%|█████████▍| 376/400 [05:02<00:19,
#                              1.24it/s, loss=0.0763, lr=2e-6]#015Steps:  94%|█████████▍| 376/400
#                              [05:02<00:19,  1.24it/s, loss=0.0708, lr=2e-6]#015Steps:
#                              94%|█████████▍| 377/400 [05:02<00:18,  1.24it/s, loss=0.0708,
#                              lr=2e-6]#015Steps:  94%|█████████▍| 377/400 [05:02<00:18,
#                              1.24it/s, loss=0.231, lr=2e-6] #015Steps:  94%|█████████▍| 378/400
#                              [05:03<00:17,  1.25it/s, loss=0.231, lr=2e-6]#015Steps:
#                              94%|█████████▍| 378/400 [05:03<00:17,  1.25it/s, loss=0.228,
#                              lr=2e-6]#015Steps:  95%|█████████▍| 379/400 [05:04<00:16,
#                              1.24it/s, loss=0.228, lr=2e-6]#015Steps:  95%|█████████▍| 379/400
#                              [05:04<00:16,  1.24it/s, loss=0.483, lr=2e-6]#015Steps:
#                              95%|█████████▌| 380/400 [05:05<00:15,  1.25it/s, loss=0.483,
#                              lr=2e-6]#015Steps:  95%|█████████▌| 380/400 [05:05<00:15,
#                              1.25it/s, loss=0.172, lr=2e-6]#015Steps:  95%|█████████▌| 381/400
#                              [05:06<00:15,  1.25it/s, loss=0.172, lr=2e-6]#015Steps:
#                              95%|█████████▌| 381/400 [05:06<00:15,  1.25it/s, loss=1.11,
#                              lr=2e-6] #015Steps:  96%|█████████▌| 382/400 [05:06<00:14,
#                              1.24it/s, loss=1.11, lr=2e-6]#015Steps:  96%|█████████▌| 382/400
#                              [05:06<00:14,  1.24it/s, loss=0.107, lr=2e-6]#015Steps:
#                              96%|█████████▌| 383/400 [05:07<00:13,  1.25it/s, loss=0.107,
#                              lr=2e-6]#015Steps:  96%|█████████▌| 383/400 [05:07<00:13,
#                              1.25it/s, loss=0.023, lr=2e-6]#015Steps:  96%|█████████▌| 384/400
#                              [05:08<00:12,  1.25it/s, loss=0.023, lr=2e-6]#015Steps:
#                              96%|█████████▌| 384/400 [05:08<00:12,  1.25it/s, loss=0.0874,
#                              lr=2e-6]#015Steps:  96%|█████████▋| 385/400 [05:09<00:12,
#                              1.24it/s, loss=0.0874, lr=2e-6]#015Steps:  96%|█████████▋| 385/400
#                              [05:09<00:12,  1.24it/s, loss=0.239, lr=2e-6] #015Steps:  96%|█
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=434330;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=142068;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ████████▋| 386/400 [05:10<00:11,  1.24it/s, loss=0.239,
#                              lr=2e-6]#015Steps:  96%|█████████▋| 386/400 [05:10<00:11,
#                              1.24it/s, loss=0.06, lr=2e-6] #015Steps:  97%|█████████▋| 387/400
#                              [05:10<00:10,  1.24it/s, loss=0.06, lr=2e-6]#015Steps:
#                              97%|█████████▋| 387/400 [05:10<00:10,  1.24it/s, loss=0.301,
#                              lr=2e-6]#015Steps:  97%|█████████▋| 388/400 [05:11<00:09,
#                              1.24it/s, loss=0.301, lr=2e-6]#015Steps:  97%|█████████▋| 388/400
#                              [05:11<00:09,  1.24it/s, loss=0.0664, lr=2e-6]#015Steps:
#                              97%|█████████▋| 389/400 [05:12<00:08,  1.24it/s, loss=0.0664,
#                              lr=2e-6]#015Steps:  97%|█████████▋| 389/400 [05:12<00:08,
#                              1.24it/s, loss=0.445, lr=2e-6] #015Steps:  98%|█████████▊| 390/400
#                              [05:13<00:08,  1.24it/s, loss=0.445, lr=2e-6]#015Steps:
#                              98%|█████████▊| 390/400 [05:13<00:08,  1.24it/s, loss=0.437,
#                              lr=2e-6]#015Steps:  98%|█████████▊| 391/400 [05:14<00:07,
#                              1.25it/s, loss=0.437, lr=2e-6]#015Steps:  98%|█████████▊| 391/400
#                              [05:14<00:07,  1.25it/s, loss=0.178, lr=2e-6]#015Steps:
#                              98%|█████████▊| 392/400 [05:14<00:06,  1.25it/s, loss=0.178,
#                              lr=2e-6]#015Steps:  98%|█████████▊| 392/400 [05:14<00:06,
#                              1.25it/s, loss=0.405, lr=2e-6]#015Steps:  98%|█████████▊| 393/400
#                              [05:15<00:05,  1.24it/s, loss=0.405, lr=2e-6]#015Steps:
#                              98%|█████████▊| 393/400 [05:15<00:05,  1.24it/s, loss=0.197,
#                              lr=2e-6]#015Steps:  98%|█████████▊| 394/400 [05:16<00:04,
#                              1.25it/s, loss=0.197, lr=2e-6]#015Steps:  98%|█████████▊| 394/400
#                              [05:16<00:04,  1.25it/s, loss=0.0865, lr=2e-6]#015Steps:
#                              99%|█████████▉| 395/400 [05:17<00:04,  1.25it/s, loss=0.0865,
#                              lr=2e-6]#015Steps:  99%|█████████▉| 395/400 [05:17<00:04,
#                              1.25it/s, loss=0.106, lr=2e-6] #015Steps:  99%|█████████▉| 396/400
#                              [05:18<00:03,  1.25it/s, loss=0.106, lr=2e-6]#015Steps:
#                              99%|█████████▉| 396/400 [05:18<00:03,  1.25it/s, loss=0.54,
#                              lr=2e-6] #015Steps:  99%|█████████▉| 397/400 [05:18<00:02,
#                              1.25it/s, loss=0.54, lr=2e-6]#015Steps:  99%|█████████▉| 397/400
#                              [05:18<00:02,  1.25it/s, loss=0.558, lr=2e-6]#015Steps:
#                              100%|█████████▉| 398/400 [05:19<00:01,  1.25it/s, loss=0.558,
#                              lr=2e-6]#015Steps: 100%|█████████▉| 398/400 [05:19<00:01,
#                              1.25it/s, loss=0.687, lr=2e-6]#015Steps: 100%|█████████▉| 399/400
#                              [05:20<00:00,  1.24it/s, loss=0.687, lr=2e-6]#015Steps:
#                              100%|█████████▉| 399/400 [05:20<00:00,  1.24it/s, loss=0.365,
#                              lr=2e-6]#015Steps: 100%|██████████| 400/400 [05:21<00:00,
#                              1.21it/s, loss=0.365, lr=2e-6]#015Steps: 100%|██████████| 400/400
#                              [05:21<00:00,  1.21it/s, loss=0.12, lr=2e-6] Reached max_teps=400.
#                              Stopping training now.
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=63187;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=760011;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              End epoch 3: train_avg_loss=0.2473553790524602
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=407161;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=555442;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Steps: 100%|██████████| 400/400 [05:21<00:00,  1.24it/s, loss=0.12,
#                              lr=2e-6]
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=612083;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=959797;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Configuration saved in /opt/ml/model/model_index.json
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=867047;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=252944;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Configuration saved in /opt/ml/model/vae/config.json
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=414214;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=709050;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Model weights saved in
#                              /opt/ml/model/vae/diffusion_pytorch_model.bin
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=558164;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=909680;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Configuration saved in /opt/ml/model/unet/config.json
# [02/11/26 11:32:21] INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=654284;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=429814;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Model weights saved in
#                              /opt/ml/model/unet/diffusion_pytorch_model.bin
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=763693;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=53140;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Configuration saved in
#                              /opt/ml/model/scheduler/scheduler_config.json
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=668671;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=985692;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              Training Container Execution Completed
#                     INFO     jumpstart-sd-v2-1-finetune-1770808353-bcb3-20260211111234/algo-1-17 ]8;id=92440;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=400892;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35869\35869]8;;\
#                              70808449:
#                              ++ echo 'Training Container Execution Completed'
# [02/11/26 11:34:08] INFO     Final Resource Status: Completed                                    ]8;id=743546;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py\resources.py]8;;\:]8;id=388405;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py#35872\35872]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training completed!

# %% [markdown]
# ### 2.4. Deploy and run inference on the fine-tuned model
#
# ---
#
# A trained model does nothing on its own. We now want to use the model to perform inference. For this example, that means predicting the bounding boxes of an image. We follow the same steps as in [2. Run inference on the pre-trained model](#2.-Run-inference-on-the-pre-trained-model). We start by retrieving the jumpstart artifacts for deploying an endpoint. However, instead of base_predictor, we  deploy the `od_estimator` that we fine-tuned.
#
# ---

# %%
import uuid
from sagemaker.core import image_uris, script_uris
from sagemaker.core.resources import Endpoint

inference_instance_type = "ml.g4dn.2xlarge"

deploy_image_uri = image_uris.retrieve(
    region=aws_region, framework=None,
    model_id=train_model_id, model_version="*",
    image_scope="inference", instance_type=inference_instance_type,
)
deploy_script_uri = script_uris.retrieve(
    model_id=train_model_id, model_version="*", script_scope="inference",
)

# Get model artifacts from training job
training_job = model_trainer._latest_training_job
model_data_url = training_job.model_artifacts.s3_model_artifacts

unique_id = str(uuid.uuid4())[:8]
ft_model_name = f"sd-ft-model-{unique_id}"
ft_endpoint_name = f"sd-ft-endpoint-{unique_id}"

sm_client = boto3.client('sagemaker', region_name=aws_region)

sm_client.create_model(
    ModelName=ft_model_name,
    PrimaryContainer={
        "Image": deploy_image_uri,
        "ModelDataUrl": model_data_url,
        "Environment": {"SAGEMAKER_PROGRAM": "inference.py", "SAGEMAKER_SUBMIT_DIRECTORY": deploy_script_uri},
    },
    ExecutionRoleArn=aws_role,
)

sm_client.create_endpoint_config(
    EndpointConfigName=ft_endpoint_name,
    ProductionVariants=[{
        "VariantName": "AllTraffic",
        "ModelName": ft_model_name,
        "InstanceType": inference_instance_type,
        "InitialInstanceCount": 1,
    }],
)

sm_client.create_endpoint(EndpointName=ft_endpoint_name, EndpointConfigName=ft_endpoint_name)

import time
while True:
    resp = sm_client.describe_endpoint(EndpointName=ft_endpoint_name)
    status = resp["EndpointStatus"]
    print(f"Status: {status}")
    if status != "Creating":
        break
    time.sleep(30)

core_endpoint = Endpoint.get(endpoint_name=ft_endpoint_name)
print(f"Endpoint deployed: {ft_endpoint_name}")
# Out:
# Using model 'model-txt2img-stabilityai-stable-diffusion-v2-1-base' with wildcard version identifier '*'. You can pin to version '2.0.17' for more stable results. Note that models may have different input/output signatures after a major version upgrade.
# [02/11/26 11:34:09] WARNING  Using model 'model-txt2img-stabilityai-stable-diffusion-v2-1-base' with   ]8;id=637421;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/jumpstart/cache.py\cache.py]8;;\:]8;id=891780;file:///opt/conda/lib/python3.12/site-packages/sagemaker/core/jumpstart/cache.py#624\624]8;;\
#                              wildcard version identifier '*'. You can pin to version '2.0.17' for more
#                              stable results. Note that models may have different input/output
#                              signatures after a major version upgrade.
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: InService
# Endpoint deployed: sd-ft-endpoint-7289fe1b

# %% [markdown]
# Next, we query the finetuned model, parse the response and display the generated image. Functions for these are implemented below. Input to the endpoint is any string of text dumped in json and encoded in `utf-8` format. Output of the endpoint is a json with generated text.

# %%
import matplotlib.pyplot as plt
import numpy as np

def query(endpoint, text):
    response = endpoint.invoke(
        body=text.encode("utf-8"),
        content_type="application/x-text",
        accept="application/json",
    )
    return response.body.read()

def parse_response(query_response):
    response_dict = json.loads(query_response)
    return response_dict["generated_image"], response_dict["prompt"]

def display_img_and_prompt(img, prmpt):
    plt.figure(figsize=(12, 12))
    plt.imshow(np.array(img))
    plt.axis("off")
    plt.title(prmpt)
    plt.show()

# %%
text = "a photo of a Doppler dog with a hat"
query_response = query(core_endpoint, text)
img, prmpt = parse_response(query_response)
display_img_and_prompt(img, prmpt)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 text = "a photo of a Doppler dog with a hat"                                                 │
# │ ❱ 2 query_response = query(core_endpoint, text)                                                  │
# │   3 img, prmpt = parse_response(query_response)                                                  │
# │   4 display_img_and_prompt(img, prmpt)                                                           │
# │   5                                                                                              │
# │                                                                                                  │
# │ in query:5                                                                                       │
# │                                                                                                  │
# │    2 import numpy as np                                                                          │
# │    3                                                                                             │
# │    4 def query(endpoint, text):                                                                  │
# │ ❱  5 │   response = endpoint.invoke(                                                             │
# │    6 │   │   body=text.encode("utf-8"),                                                          │
# │    7 │   │   content_type="application/x-text",                                                  │
# │    8 │   │   accept="application/json",                                                          │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py:143 in wrapper               │
# │                                                                                                  │
# │     140 │   │   @functools.wraps(func)                                                           │
# │     141 │   │   def wrapper(*args, **kwargs):                                                    │
# │     142 │   │   │   config = dict(arbitrary_types_allowed=True)                                  │
# │ ❱   143 │   │   │   return validate_call(config=config)(func)(*args, **kwargs)                   │
# │     144 │   │                                                                                    │
# │     145 │   │   return wrapper                                                                   │
# │     146                                                                                          │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:39 in               │
# │ wrapper_function                                                                                 │
# │                                                                                                  │
# │    36 │   │                                                                                      │
# │    37 │   │   @functools.wraps(wrapped)                                                          │
# │    38 │   │   def wrapper_function(*args, **kwargs):                                             │
# │ ❱  39 │   │   │   return wrapper(*args, **kwargs)                                                │
# │    40 │                                                                                          │
# │    41 │   # We need to manually update this because `partial` object has no `__name__` and `__   │
# │    42 │   wrapper_function.__name__ = extract_function_name(wrapped)                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:136 in __call__     │
# │                                                                                                  │
# │   133 │   │   if not self.__pydantic_complete__:                                                 │
# │   134 │   │   │   self._create_validators()                                                      │
# │   135 │   │                                                                                      │
# │ ❱ 136 │   │   res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args,   │
# │   137 │   │   if self.__return_pydantic_validator__:                                             │
# │   138 │   │   │   return self.__return_pydantic_validator__(res)                                 │
# │   139 │   │   else:                                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/resources.py:11291 in invoke              │
# │                                                                                                  │
# │   11288 │   │   │   "SessionId": session_id,                                                     │
# │   11289 │   │   }                                                                                │
# │   11290 │   │   # serialize the input request                                                    │
# │ ❱ 11291 │   │   operation_input_args = serialize(operation_input_args)                           │
# │   11292 │   │   logger.debug(f"Serialized input request: {operation_input_args}")                │
# │   11293 │   │                                                                                    │
# │   11294 │   │   client = Base.get_sagemaker_client(                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py:503 in serialize           │
# │                                                                                                  │
# │   500 │   │   return value                                                                       │
# │   501 │   elif isinstance(value, Dict):                                                          │
# │   502 │   │   # if the value is a dict, use _serialize_dict() to serialize it recursively        │
# │ ❱ 503 │   │   return _serialize_dict(value)                                                      │
# │   504 │   elif isinstance(value, List):                                                          │
# │   505 │   │   # if the value is a dict, use _serialize_list() to serialize it recursively        │
# │   506 │   │   return _serialize_list(value)                                                      │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py:526 in _serialize_dict     │
# │                                                                                                  │
# │   523 │   """                                                                                    │
# │   524 │   serialized_dict = {}                                                                   │
# │   525 │   for k, v in value.items():                                                             │
# │ ❱ 526 │   │   if serialize_result := serialize(v):                                               │
# │   527 │   │   │   serialized_dict.update({k: serialize_result})                                  │
# │   528 │   return serialized_dict                                                                 │
# │   529                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py:509 in serialize           │
# │                                                                                                  │
# │   506 │   │   return _serialize_list(value)                                                      │
# │   507 │   elif is_not_primitive(value):                                                          │
# │   508 │   │   # if the value is a dict, use _serialize_shape() to serialize it recursively       │
# │ ❱ 509 │   │   return _serialize_shape(value)                                                     │
# │   510 │   else:                                                                                  │
# │   511 │   │   return value                                                                       │
# │   512                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.12/site-packages/sagemaker/core/utils/utils.py:559 in _serialize_shape    │
# │                                                                                                  │
# │   556 │   │   dict: The dict of serialized shape                                                 │
# │   557 │   """                                                                                    │
# │   558 │   serialized_dict = {}                                                                   │
# │ ❱ 559 │   for k, v in vars(value).items():                                                       │
# │   560 │   │   if serialize_result := serialize(v):                                               │
# │   561 │   │   │   key = snake_to_pascal(k) if is_snake_case(k) else k                            │
# │   562 │   │   │   serialized_dict.update({key[0].upper() + key[1:]: serialize_result})           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: vars() argument must have __dict__ attribute

# %% [markdown]
# All the parameters mentioned in [2.4. Supported Inference parameters](#2.4.-Supported-Inference-parameters) are supported with finetuned model as well. You may also receive compressed image output as in [2.5. Compressed Image Output](#2.5.-Compressed-Image-Output) by changing `accept`.

# %% [markdown]
# ---
# Next, we delete the endpoint corresponding to the finetuned model.
#
# ---

# %%
# Cleanup
sm_client.delete_endpoint(EndpointName=ft_endpoint_name)
sm_client.delete_endpoint_config(EndpointConfigName=ft_endpoint_name)
sm_client.delete_model(ModelName=ft_model_name)
print("All resources deleted!")

# %% [markdown]
# ## 3. Conclusion
# ---
#
# Although creating impressive images can find use in industries ranging from art to NFTs and beyond, today we also expect AI to be personalizable. JumpStart provides fine-tuning capability to the pre-trained models so that you can adapt the model to your own use case with as little as five training images. This can be useful when creating art, logos, custom designs, NFTs, and so on, or fun stuff such as generating custom AI images of your pets or avatars of yourself. In this lab, we learned how to fine-tune a stable diffusion text to image generation model. To learn more about Stable Diffusion fine-tuning, please check out the blog [Fine-tune text-to-image Stable Diffusion models with Amazon SageMaker JumpStart](https://aws.amazon.com/blogs/machine-learning/fine-tune-text-to-image-stable-diffusion-models-with-amazon-sagemaker-jumpstart/).
